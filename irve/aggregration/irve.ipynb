# %% [markdown]
# # Consolidation IRVE

# %%
import requests
import agate
import agateexcel

from pathlib import Path
import cchardet as chardet

# %%
# get the list of datasets tagged irve on data.gouv.fr

url = 'https://www.data.gouv.fr/api/1/datasets/?tag=irve&page_size=1000'
r = requests.get(url)
datasets = r.json()['data']

# %%
# Download all tabular files in data/ directory, as best as we can

downloaded = []
for d in datasets:
    orga = d['organization']['slug'] if d['organization'] else d['owner']['slug']
    for r in d['resources']:
        rurl = r['url']
        # ODS style NB: won't work more than once for CKAN
        if 'format=csv' in rurl:
            filename = rurl.split('/')[-3] + '.csv'
        else:
            filename = rurl.split('/')[-1]
        if filename in downloaded:
            print('x existing file %s' % rurl)
            continue
        ext = filename.split('.')[-1]
        if ext not in ['csv', 'xls', 'xlsx']:
            print('x ignored file %s' % rurl)
            continue
        r = requests.get(rurl, allow_redirects=True)
        p = Path('data/%s' % orga)
        p.mkdir(exist_ok=True)
        with open('%s/%s' % (p, filename), 'wb') as f:
            f.write(r.content)
            downloaded.append(filename)
            print('- downloaded file [%s] %s' % (filename, rurl))
print('Done')
# Out:
# - downloaded file [IRVE_Data_Gouv_Rambouilllet_Territoires.xlsx] https://www.data.gouv.fr/s/resources/bornes-de-recharge-de-rambouillet-territoires/20180511-093502/IRVE_Data_Gouv_Rambouilllet_Territoires.xlsx
# - downloaded file [BDD_IRVE-RT78.csv] https://www.data.gouv.fr/s/resources/irve-de-rambouillet-territoires/20161025-134007/BDD_IRVE-RT78.csv
# - downloaded file [liste_bornes_CAMVS_2017.xlsx] https://www.data.gouv.fr/s/resources/reseau-de-bornes-de-recharge-pour-vehicules-electrique-sur-la-territoire-de-lagglomeration-maubeuge-val-de-sambre/20170905-171948/liste_bornes_CAMVS_2017.xlsx
# - downloaded file [IRVE_SDEA_20180503.csv] https://www.data.gouv.fr/s/resources/bornes-de-recharge-de-laube-irve/20180503-181544/IRVE_SDEA_20180503.csv
# - downloaded file [IRVE_SYDEV_20180502.csv] https://www.data.gouv.fr/s/resources/stations-de-recharge-pour-vehicules-electriques-sur-le-territoire-vendeen/20180502-104237/IRVE_SYDEV_20180502.csv
# - downloaded file [IRVE_VILLEDEBEAUVAIS_20170320.csv] https://www.data.gouv.fr/s/resources/bornes-de-recharge-de-la-ville-de-beauvais/20170320-135208/IRVE_VILLEDEBEAUVAIS_20170320.csv
# - downloaded file [IRVE_SDE29_20180404.csv] https://www.data.gouv.fr/s/resources/bornes-de-recharge-pour-vehicules-electriques-sde29/20180404-113045/IRVE_SDE29_20180404.csv
# - downloaded file [IRVE_SDE29_20170822.csv] https://www.data.gouv.fr/s/resources/bornes-de-recharge-pour-vehicules-electriques-sde29/20170822-154109/IRVE_SDE29_20170822.csv
# - downloaded file [IRVE_SDE29_20170515.csv] https://www.data.gouv.fr/s/resources/bornes-de-recharge-pour-vehicules-electriques-sde29/20170523-150556/IRVE_SDE29_20170515.csv
# - downloaded file [IRVE_SDE29_20170126.csv] https://www.data.gouv.fr/s/resources/bornes-de-recharge-pour-vehicules-electriques-sde29/20170208-155651/IRVE_SDE29_20170126.csv
# - downloaded file [Stations-recharge-VE-Se61_01_03_2017.xlsx] https://www.data.gouv.fr/s/resources/se61-infrastructures-de-recharge-pour-vehicules-electriques-dans-lorne-61/20170301-202526/Stations-recharge-VE-Se61_01_03_2017.xlsx
# - downloaded file [Stations-recharge-VE-Se61_29_11_2016.xlsx] https://www.data.gouv.fr/s/resources/se61-infrastructures-de-recharge-pour-vehicules-electriques-dans-lorne-61/20161129-175841/Stations-recharge-VE-Se61_29_11_2016.xlsx
csv] https://www.data.gouv.fr/s/resources/infrastructures-de-recharge-pour-vehicules-electriques-irve-1/20180718-113917/IRVE_WiiiZCAPG_20180712_WGS.csv
# x existing file https://www.data.gouv.fr/s/resources/irve-sied70-recensement-et-information/20180725-115208/Recensement_MAJ_250718.xls
# - downloaded file [IRVE_MObiVE_20180625.csv] https://www.data.gouv.fr/s/resources/infrastructures-de-recharge-pour-vehicules-electriques-mobive/20180625-180816/IRVE_MObiVE_20180625.csv
# - downloaded file [IRVE_CCHVC180222.csv] https://www.data.gouv.fr/s/resources/bornes-de-recharge-de-la-cchvc-communaute-de-communes-de-la-haute-vallee-de-chevreuse-1/20180222-115126/IRVE_CCHVC180222.csv
# - downloaded file [BornesRecharge2014_1.xlsx] https://www.data.gouv.fr/_uploads/resources/BornesRecharge2014_1.xlsx
# - downloaded file [IRVE_TEM53_20180528.csv] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-te53/20180810-083420/IRVE_TEM53_20180528.csv
# - downloaded file [irve-sedi-20180905.csv] https://static.data.gouv.fr/resources/sedi-bornes-de-recharge-pour-vehicule-electrique/20180907-144159/irve-sedi-20180905.csv
# - downloaded file [dataset.csv] http://opendata.paris.fr/explore/dataset/stations_et_espaces_autolib_de_la_metropole_parisienne/download?format=csv
# x ignored file http://opendata.paris.fr/explore/dataset/stations_et_espaces_autolib_de_la_metropole_parisienne/download?format=json
# x ignored file http://opendata.paris.fr/explore/dataset/stations_et_espaces_autolib_de_la_metropole_parisienne/download?format=xls
# x ignored file http://opendata.paris.fr/explore/dataset/stations_et_espaces_autolib_de_la_metropole_parisienne/download?format=shp
# x existing file http://opendata.paris.fr/explore/dataset/stations_et_espaces_autolib_de_la_metropole_parisienne/download?format=csv
# x ignored file http://opendata.paris.fr/explore/dataset/stations_et_espaces_autolib_de_la_metropole_parisienne/download?format=json
# x ignored file http://opendata.paris.fr/explore/dataset/stations_et_espaces_autolib_de_la_metropole_parisienne/download?format=xls
# x ignored file http://opendata.paris.fr/explore/dataset/stations_et_espaces_autolib_de_la_metropole_parisienne/download?format=shp
# - downloaded file [IRVE_WiiiZCASA_20180514.csv] https://www.data.gouv.fr/s/resources/infrastructures-de-recharge-pour-vehicules-electriques-irve/20180522-164130/IRVE_WiiiZCASA_20180514.csv
# x ignored file https://www.data.gouv.fr/s/resources/infrastructures-de-recharge-pour-vehicules-electriques-irve/20180606-095553/IRVE_WiiizCASA_20180514_METADATA.xml
# - downloaded file [IRVE_USEDADIRVE02_20180806.csv] https://static.data.gouv.fr/resources/useda-dirve02/20180806-152252/IRVE_USEDADIRVE02_20180806.csv
# - downloaded file [IRVE_USEDADIRVE02_20180125.csv] https://www.data.gouv.fr/s/resources/useda-dirve02/20180125-160036/IRVE_USEDADIRVE02_20180125.csv
# - downloaded file [IRVE_USEDADIRVE02_20170623.csv] https://www.data.gouv.fr/s/resources/useda-dirve02/20170623-143528/IRVE_USEDADIRVE02_20170623.csv
# - downloaded file [IRVE_USEDADIRVE02_20170316.csv] https://www.data.gouv.fr/s/resources/useda-dirve02/20170316-111520/IRVE_USEDADIRVE02_20170316.csv
# - downloaded file [IRVE_USEDADIRVE02_20170207.csv] https://www.data.gouv.fr/s/resources/useda-dirve02/20170207-144515/IRVE_USEDADIRVE02_20170207.csv
# - downloaded file [IRVE_USEDADIRVE02_20170120.csv] https://www.data.gouv.fr/s/resources/useda-dirve02/20170123-081540/IRVE_USEDADIRVE02_20170120.csv
# - downloaded file [fichier-consolide-des-bornes-de-recharge-pour-vehicules-electriques-irve.csv] https://data.issy.com//explore/dataset/fichier-consolide-des-bornes-de-recharge-pour-vehicules-electriques-irve/download?format=csv&timezone=Europe/Berlin&use_labels_for_header=true
# x ignored file https://data.issy.com//explore/dataset/fichier-consolide-des-bornes-de-recharge-pour-vehicules-electriques-irve/download?format=json&timezone=Europe/Berlin&use_labels_for_header=true
# x ignored file https://data.issy.com//explore/dataset/fichier-consolide-des-bornes-de-recharge-pour-vehicules-electriques-irve/download?format=geojson&timezone=Europe/Berlin&use_labels_for_header=true
# x ignored file https://data.issy.com//explore/dataset/fichier-consolide-des-bornes-de-recharge-pour-vehicules-electriques-irve/download?format=shp&timezone=Europe/Berlin&use_labels_for_header=true
# - downloaded file [IRVE_SIEGE27_20171130.csv] https://www.data.gouv.fr/s/resources/reseau-de-bornes-de-recharge-pour-vehicules-electriques-irve/20171211-152031/IRVE_SIEGE27_20171130.csv
# - downloaded file [IRVE_SIEGE27_20171130.xlsx] https://www.data.gouv.fr/s/resources/reseau-de-bornes-de-recharge-pour-vehicules-electriques-irve/20171211-152015/IRVE_SIEGE27_20171130.xlsx
# - downloaded file [IRVE_SEIPC.csv] https://www.data.gouv.fr/s/resources/bornes-de-rec
# - downloaded file [irve-istres-20180906.csv] https://static.data.gouv.fr/resources/e-mouv-istres-bornes-de-recharge-pour-vehicule-electrique/20180907-151030/irve-istres-20180906.csv
# - downloaded file [bornes-recharge-agregation-region-reference.csv] https://trouver.datasud.fr/dataset/400beba7-5c2e-4097-a718-53262baa2ed0/resource/a8804867-c69f-466c-bb30-ccd7633431c6/download/bornes-recharge-agregation-region-reference.csv
# - downloaded file [IRVE_SIMONE_20180528.csv] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-simone-1/20180810-083350/IRVE_SIMONE_20180528.csv

# %%
def parse_csv(file_path):
    with file_path.open('rb') as f:
        encoding = chardet.detect(f.read()).get('encoding')
    try:
        table = agate.Table.from_csv(file_path, encoding=encoding, sniff_limit=4096)
    except Exception as e:
        print('\t CSV parse error: %s' % e)
    else:
        return table

# %%
# parse CSV files: analyze difference between standard schema and real data
# infer a mapping of column names variation to match a maximum of data later

columns_mapping = [
    ('n_amenageur', 'nom_amenageur', 'n_amenageu'), 
    ('n_operateur', 'n_operateu'), 
    ('n_enseigne', ), 
    ('id_station', ), 
    ('n_station', 'nom_station'), 
    ('ad_station', 'adresse_station'), 
    ('code_insee', ), 
    ('Xlongitude', 'longitude_wsg84'), 
    ('Ylatitude', 'latitude_wsg84'), 
    ('nbre_pdc', 'nbre_borne'), 
    ('id_pdc', 'n° borne'), 
    ('puiss_max', ), 
    ('type_prise', 'type_connecteur', 'typ_charge'), 
    ('acces_recharge', 'modalité d\'accès à la borne', 'acces_rech'), 
    ('accessibilité', 'accessibilitã©', 'accessibilite', 'accessibilit�', 'accessibilit‚'), 
    ('observations', ), 
    ('date_maj', ),
]
columns = ['n_amenageur', 'n_operateur', 'n_enseigne', 'id_station', 'n_station', 'ad_station', 'code_insee', 'Xlongitude', 'Ylatitude', 'nbre_pdc', 'id_pdc', 'puiss_max', 'type_prise', 'acces_recharge', 'accessibilité', 'observations', 'date_maj']
columns_low = [x.lower() for x in columns]

p = Path('data')
for child in [x for x in p.iterdir() if x.is_dir()]:
    csvs = list(child.glob('*.csv'))
    for csv in csvs:
        table = parse_csv(csv)
        if table:
            cols = [x.lower() for x in table.column_names]
            missing_pivot = []
            for pivot in ['id_station', 'id_pdc', 'date_maj']:
                if pivot not in cols:
                    missing_pivot.append(pivot)
            if missing_pivot:
                print('Skipping %s for missing pivot %s, cols were %s' % (csv, missing_pivot, cols))
                break
            diff = list(set(cols) - set(columns_low))
            if diff:
                print('DIFF for %s: %s' % (csv, diff))
print('Done.')
# Out:
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 0 has no name. Using "a".
# DIFF for data/region-provence-alpes-cote-d-azur/bornes-recharge-agregation-region-reference.csv: ['etat', 'n° borne', 'type', 'financement région', 'commune  de a à z', 'date mise en service', 'a', 'accessibilite', 'state', 'nbre_borne']
# DIFF for data/aurelien-ouellette/data_gouv_18.csv: ['accessibilitã©']
# DIFF for data/aurelien-ouellette/Reseau_Brevcar_09042018.csv: ['accessibilitã©']
# DIFF for data/aurelien-ouellette/IRVE_SDE76_20180411.csv: ['accessibilitã©']
# DIFF for data/aurelien-ouellette/20180711Opendata_ADP.csv: ['accessibilitã©']
# DIFF for data/gabrielle-caro/irve-sedi-20180905.csv: ['accessibilite']
# DIFF for data/gabrielle-caro/irve-sieeen-20180905.csv: ['accessibilite']
# DIFF for data/gabrielle-caro/irve-syme05-20180905.csv: ['accessibilite']
# DIFF for data/gabrielle-caro/irve-sded-20180905.csv: ['accessibilite']
# DIFF for data/gabrielle-caro/irve-syane-20180905.csv: ['accessibilite']
# DIFF for data/gabrielle-caro/irve-istres-20180906.csv: ['accessibilite']
# DIFF for data/gabrielle-caro/irve-sdey-20180905.csv: ['accessibilite']
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 17 has no name. Using "r".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 18 has no name. Using "s".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 19 has no name. Using "t".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 20 has no name. Using "u".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 21 has no name. Using "v".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 22 has no name. Using "w".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 23 has no name. Using "x".
# Skipping data/communaute-dagglomeration-du-douaisis/LocalisationBornesElectCAD.csv for missing pivot ['id_station', 'id_pdc', 'date_maj'], cols were ['numéro de la borne ', 'commune  ', 'nom de la borne ', "adresse d'implantation", 'code postal', 'puissance électrique ', 'y_coord_cc50', 'x_coord_cc50', 'point_x_wgs84', 'point_y_wgs84']
# DIFF for data/soregies/irve-soregies-20180831.csv: ['r', 'w', 'v', 'u', 's', 'accessibilite', 'x', 't']
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 11 has no name. Using "l".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 12 has no name. Using "m".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 13 has no name. Using "n".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 14 has no name. Using "o".
# Skipping data/parking-effia-effia-stationnement/Stations-recharge-VE-EFFIA.csv for missing pivot ['id_pdc'], cols were ['id_station', 'nom_station', 'adresse_station', 'latitude_wsg84', 'longitude_wsg84', 'nom_porteur', 'type_charge', 'nbre_pdc', 'type_connecteur', 'date_maj', 'observations', 'l', 'm', 'n', 'o']
# DIFF for data/service-sig-sdef/IRVE_SDE29_20170822.csv: ['accessibilite']
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 17 has no name. Using "r".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 18 has no name. Using "s".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 19 has no name. Using "t".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 20 has no name. Using "u".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 21 has no name. Using "v".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 22 has no name. Using "w".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 23 has no name. Using "x".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 24 has no name. Using "y".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 25 has no name. Using "z".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 26 has no name. Using "aa".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 27 has no name. Using "bb".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 28 has no name. Using "cc".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 29 has no name. Using "dd".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 30 has no name. Using "ee".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 31 has no name. Using "ff".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 32 has no name. Using "gg".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 33 has no name. Using "hh".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 34 has no name. Using "ii".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 35 has no name. Using "jj".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 36 has no name. Using "kk".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 37 has no name. Using "ll".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 38 has no name. Using "mm".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 39 has no name. Using "nn".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 40 has no name. Using "oo".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 41 has no name. Using "pp".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 42 has no name. Using "qq".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 43 has no name. Using "rr".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 44 has no name. Using "ss".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 45 has no name. Using "tt".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 46 has no name. Using "uu".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 47 has no name. Using "vv".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 48 has no name. Using "ww".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 49 has no name. Using "xx".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 50 has no name. Using "yy".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 51 has no name. Using "zz".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 52 has no name. Using "aaa".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 53 has no name. Using "bbb".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 54 has no name. Using "ccc".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 55 has no name. Using "ddd".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 56 has no name. Using "eee".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 57 has no name. Using "fff".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 58 has no name. Using "ggg".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 59 has no name. Using "hhh".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 60 has no name. Using "iii".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 61 has no name. Using "jjj".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 62 has no name. Using "kkk".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 63 has no name. Using "lll".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 64 has no name. Using "mmm".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 65 has no name. Using "nnn".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 66 has no name. Using "ooo".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 67 has no name. Using "ppp".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 68 has no name. Using "qqq".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 69 has no name. Using "rrr".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 70 has no name. Using "sss".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 71 has no name. Using "ttt".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 72 has no name. Using "uuu".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 73 has no name. Using "vvv".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 74 has no name. Using "www".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 75 has no name. Using "xxx".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 76 has no name. Using "yyy".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 77 has no name. Using "zzz".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 78 has no name. Using "aaaa".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 79 has no name. Using "bbbb".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 80 has no name. Using "cccc".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 81 has no name. Using "dddd".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 82 has no name. Using "eeee".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 83 has no name. Using "ffff".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 84 has no name. Using "gggg".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 85 has no name. Using "hhhh".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 86 has no name. Using "iiii".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 87 has no name. Using "jjjj".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 88 has no name. Using "kkkk".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 89 has no name. Using "llll".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 90 has no name. Using "mmmm".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 91 has no name. Using "nnnn".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 92 has no name. Using "oooo".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 93 has no name. Using "pppp".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 94 has no name. Using "qqqq".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 95 has no name. Using "rrrr".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 96 has no name. Using "ssss".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 97 has no name. Using "tttt".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 98 has no name. Using "uuuu".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 99 has no name. Using "vvvv".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 100 has no name. Using "wwww".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 101 has no name. Using "xxxx".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 102 has no name. Using "yyyy".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 103 has no name. Using "zzzz".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 104 has no name. Using "aaaaa".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 105 has no name. Using "bbbbb".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 106 has no name. Using "ccccc".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 107 has no name. Using "ddddd".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 108 has no name. Using "eeeee".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 109 has no name. Using "fffff".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 110 has no name. Using "ggggg".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 111 has no name. Using "hhhhh".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 112 has no name. Using "iiiii".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 113 has no name. Using "jjjjj".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 114 has no name. Using "kkkkk".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 115 has no name. Using "lllll".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 116 has no name. Using "mmmmm".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 117 has no name. Using "nnnnn".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 118 has no name. Using "ooooo".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 119 has no name. Using "ppppp".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 120 has no name. Using "qqqqq".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 121 has no name. Using "rrrrr".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 122 has no name. Using "sssss".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 123 has no name. Using "ttttt".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 124 has no name. Using "uuuuu".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 125 has no name. Using "vvvvv".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 126 has no name. Using "wwwww".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 127 has no name. Using "xxxxx".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 128 has no name. Using "yyyyy".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 129 has no name. Using "zzzzz".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 130 has no name. Using "aaaaaa".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 131 has no name. Using "bbbbbb".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 132 has no name. Using "cccccc".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 133 has no name. Using "dddddd".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 134 has no name. Using "eeeeee".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 135 has no name. Using "ffffff".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 136 has no name. Using "gggggg".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 137 has no name. Using "hhhhhh".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 138 has no name. Using "iiiiii".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 139 has no name. Using "jjjjjj".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 140 has no name. Using "kkkkkk".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 141 has no name. Using "llllll".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 142 has no name. Using "mmmmmm".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 143 has no name. Using "nnnnnn".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 144 has no name. Using "oooooo".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 145 has no name. Using "pppppp".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 146 has no name. Using "qqqqqq".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 147 has no name. Using "rrrrrr".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 148 has no name. Using "ssssss".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 149 has no name. Using "tttttt".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 150 has no name. Using "uuuuuu".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 151 has no name. Using "vvvvvv".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 152 has no name. Using "wwwwww".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 153 has no name. Using "xxxxxx".
# DIFF for data/service-sig-sdef/IRVE_SDE29_20180404.csv: ['rrrr', 'u', 'dddddd', 'mm', 'oo', 'aaaa', 'rrrrrr', 'xxxxx', 'aa', 'mmmmm', 'eee', 'uuuuu', 'nnnnnn', 'mmm', 'cc', 'zz', 'www', 'w', 'ooooo', 'vvvvvv', 'ee', 'dd', 'uuuu', 'kkk', 'ddd', 'oooooo', 'mmmm', 'aaaaaa', 'ttt', 'ppppp', 's', 'ggg', 'll', 'lllll', 'ccccc', 'oooo', 'hhhhhh', 'wwwww', 'aaa', 'nn', 'rrr', 'jj', 'ff', 'qqqq', 'r', 'z', 'tttttt', 'xxxx', 'bbbb', 'hhhh', 'hhhhh', 'jjjjjj', 'cccccc', 'x', 'rr', 'wwwwww', 'jjjj', 'pppppp', 'ii', 'ttttt', 'pppp', 'vvv', 'bbb', 'nnn', 'eeeee', 'mmmmmm', 'jjjjj', 'zzzzz', 'vvvv', 'v', 'xxx', 'llllll', 'pp', 'jjj', 'sssss', 'gg', 'ssss', 'gggg', 'xx', 'qq', 'qqq', 'llll', 't', 'uu', 'hh', 'ww', 'iiii', 'nnnn', 'iiiiii', 'ddddd', 'zzz', 'iiiii', 'bb', 'kkkkkk', 'ss', 'kkkkk', 'ffffff', 'bbbbb', 'hhh', 'vv', 'y', 'yy', 'yyyy', 'wwww', 'yyyyy', 'eeee', 'ooo', 'qqqqqq', 'ffff', 'ssssss', 'accessibilite', 'sss', 'eeeeee', 'uuu', 'dddd', 'nnnnn', 'iii', 'ppp', 'xxxxxx', 'vvvvv', 'kk', 'tt', 'qqqqq', 'uuuuuu', 'lll', 'yyy', 'aaaaa', 'fff', 'gggggg', 'bbbbbb', 'cccc', 'zzzz', 'ggggg', 'ccc', 'rrrrr', 'kkkk', 'fffff', 'tttt']
# DIFF for data/service-sig-sdef/IRVE_SDE29_20170126.csv: ['accessibilite']
# DIFF for data/service-sig-sdef/IRVE_SDE29_20170515.csv: ['accessibilite']
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 17 has no name. Using "r".
# DIFF for data/union-des-secteurs-denergie-du-departement-de-laisne/IRVE_USEDADIRVE02_20170120.csv: ['r', 'longitude_wsg84', 'adresse_station', 'nom_amenageur', 'latitude_wsg84', 'nom_station']
# DIFF for data/union-des-secteurs-denergie-du-departement-de-laisne/IRVE_USEDADIRVE02_20170316.csv: ['r', 'longitude_wsg84', 'adresse_station', 'nom_amenageur', 'latitude_wsg84', 'nom_station']
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 17 has no name. Using "r".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 17 has no name. Using "r".
# DIFF for data/union-des-secteurs-denergie-du-departement-de-laisne/IRVE_USEDADIRVE02_20170623.csv: ['r', 'longitude_wsg84', 'accessibilit�', 'adresse_station', 'nom_amenageur', 'latitude_wsg84', 'nom_station']
# DIFF for data/union-des-secteurs-denergie-du-departement-de-laisne/IRVE_USEDADIRVE02_20170207.csv: ['longitude_wsg84', 'adresse_station', 'nom_amenageur', 'latitude_wsg84', 'nom_station']
# DIFF for data/union-des-secteurs-denergie-du-departement-de-laisne/IRVE_USEDADIRVE02_20180125.csv: ['longitude_wsg84', 'adresse_station', 'nom_amenageur', 'latitude_wsg84', 'nom_station']
# DIFF for data/union-des-secteurs-denergie-du-departement-de-laisne/IRVE_USEDADIRVE02_20180806.csv: ['longitude_wsg84', 'accessibilit�', 'adresse_station', 'nom_amenageur', 'latitude_wsg84', 'nom_station']
# Skipping data/etalab/IRVE-201510.csv for missing pivot ['id_pdc'], cols were ['id_station', 'nom_station', 'adresse_station', 'latitude', 'longitude', 'nom_porteur', 'type_charge', 'nbre_pdc', 'type_connecteur', 'date_maj', 'observations', 'source']
# DIFF for data/david-baufreton/IRVE_reseauAlterBase_20171116.CSV.csv: ['accessibilite']
# DIFF for data/david-baufreton/IRVE_reseauAlterBase_20170213.CSV.csv: ['accessibilite']
# DIFF for data/cnr/IRVE_CNR_20180420.csv: ['modele de borne', 'fabricant borne', 'téléphone', 'accessibilite', "modalité d'accès à la borne"]
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 17 has no name. Using "r".
# DIFF for data/cnr/IRVE_CNR_20170731.csv: ['r', 'accessibilite']
# DIFF for data/cnr/50_IRVE_CNR_20170210.csv: ['accessibilite']
# DIFF for data/cnr/IRVE_CNR_20170330.csv: ['accessibilite']
# DIFF for data/syndicat-departemental-denergie-de-laube-1/IRVE_SDEA_20180503.csv: ['accessibilită©']
# DIFF for data/helene-singez/IRVE_PASS_PASS_ELECTRIQUE_Valenciennes_Metropole.csv: ['accessibilitã©']
# DIFF for data/syndicat-departemental-denergie-du-cher/IRVE_SDE18_20171120.csv: ['accessibilite']
# Skipping data/communaute-dagglomeration-de-nevers/BORNE_RECHARGE_ELECTRIQUE_WGS84.csv for missing pivot ['id_station', 'id_pdc', 'date_maj'], cols were ['id', 'adresse', 'commune', 'proprietai', 'deploiemen', 'numero', 'puissance', 'mode_de_ch', 'coord_x', 'coord_y']
# 	 CSV parse error: Row 0 has 13 values, but Table only has 11 columns.
# 	 CSV parse error: Row 0 has 18 values, but Table only has 16 columns.
# DIFF for data/syndicat-departemental-denergies-de-lardeche/irve-sde07-20180905.csv: ['accessibilite']
# Skipping data/rennes-metropole-en-acces-libre-1/bornes-de-recharge-dediees-aux-vehicules-electriques-sur-le-territoire-de-rennes.csv for missing pivot ['id_station', 'id_pdc', 'date_maj'], cols were ['geo point', 'geo shape', 'gml_id', 'objectid', 'id', 'c_insee', 'site_nom', 'site_adr', 'site_etat', 'invest', 'site_type', 'i_acces', 'i_modal', 'i_tarif', 'b_type', 'p_domestic', 'p_type2', 'p_type3', 'p_type4', 'p_ccs', 'ch_normale', 'ch_rapide', 'ch_acceler', 'maj_date', 'x_cc48', 'y_cc48']
# DIFF for data/saint-louis-agglomeration-izyborne/irve-saint-louis-20180814.csv: ['accessibilite']
# Skipping data/renault-sas/d-localdata-a186081-desktop-infra-recharge-reseau-renault-france.csv for missing pivot ['id_pdc'], cols were ['id_station', 'nom_station', 'adresse_station', 'longitude_wsg84', 'latitude_wsg84', 'nom_porteur', 'type_charge', 'nbre_pdc', 'type_connecteur', 'date_maj', 'observation']
# Skipping data/clem-mobilite-1/OpenData-prises-Clem-mobilite.csv for missing pivot ['id_station', 'id_pdc', 'date_maj'], cols were ['nom', 'latitude', 'longitude', 'adresse_rue', 'code_postal', 'ville', 'id_clem']
# DIFF for data/servane-macheto/IRVE_SDEHG_20180720.csv: ['modele de borne', 'fabricant borne', 'téléphone', 'accessibilite', "modalité d'accès à la borne"]
# Skipping data/alban-raffray/IRVE_MOBISDEC_20180209.csv for missing pivot ['id_station'], cols were ['n_amenageur', 'n_operateur', 'n_enseigne', 'id_station_mobisdec', 'n_station', 'ad_station', 'code_insee', 'xlongitude', 'ylatitude', 'nbre_pdc', 'id_pdc', 'puiss_max', 'type_prise', 'acces_recharge', 'accessibilité', 'observations', 'date_maj']
# Skipping data/mairie-de-paris/dataset.csv for missing pivot ['id_station', 'id_pdc', 'date_maj'], cols were ['ville', 'abri', 'id_dsp', 'id_autolib', 'adresse', 'cp', 'prises_autolib', 'prises_tiers_t3', 'type', 'xy']
# DIFF for data/communaute-dagglomeration-du-pays-de-grasse/IRVE_WiiiZCAPG_20180712_WGS.csv: ['accessibilit‚']
# DIFF for data/plus-de-bornes/IRVE_PlusDeBornes_20170314.csv: ['accessibilite']
# Skipping data/plus-de-bornes/opendataPlusDeBornes.csv for missing pivot ['id_station', 'id_pdc', 'date_maj'], cols were ['[id_station];[nom_station];[adresse_station];[latitude_wsg84];[longitude_wsg84];[nom_porteur]; [type_charge]; [nbre_pdc];[type_connecteur]; [date_maj]; [observations]']
# Skipping data/rambouillet-territoires/BDD_IRVE-RT78.csv for missing pivot ['id_pdc'], cols were ['id_station', 'nom_station', 'adresse_station', 'latitude_wsg84', 'longitude_wsg84', 'nom_porteur', 'type_charge', 'nbre_pdc', 'type_connecteur', 'date_maj', 'observations']
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 0 has no name. Using "a".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 1 has no name. Using "b".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 17 has no name. Using "r".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 18 has no name. Using "s".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 19 has no name. Using "t".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 20 has no name. Using "u".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 21 has no name. Using "v".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 22 has no name. Using "w".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 23 has no name. Using "x".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 24 has no name. Using "y".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 25 has no name. Using "z".
# DIFF for data/mairie-de-sainte-adresse/IRVE_SAINTEADRESSE_01062018.csv: ['r', 'z', 'b', 'w', 'v', 'u', 's', 'y', 'a', 'accessibilite', 'x', 't']
# Skipping data/saemes/points-recharges-electriques-parkings.csv for missing pivot ['id_station', 'id_pdc', 'date_maj'], cols were ['source data', 'n° point recharge electrique', 'code parking concerné', 'nom parking', 'type véhicule', 'puissance en kw', 'recharge accessible au public ou réservé aux abonnés', 'niveau du parking de la borne', 'coût de la recharge (€/heure)', 'paiement recharge  compte kiwhi', 'paiement recharge  compte freshmile', 'geo', 'code postal']
# DIFF for data/patrice-lozere/IRVE_SDEY_YONNE_20170519.csv: ['commune', 'n_amenageu', 'n_operateu', 'acces_rech', 'accessibilite', 'typ_charge']
# Skipping data/ville-d-issy-les-moulineaux/fichier-consolide-des-bornes-de-recharge-pour-vehicules-electriques-irve.csv for missing pivot ['id_station', 'id_pdc', 'date_maj'], cols were ['{']
# DIFF for data/syndicat-intercommunal-de-distribution-denergie-de-loir-et-cher/IRVE_SIDELC_20171011.csv: ['accessibilite']
# DIFF for data/communaute-dagglomeration-du-boulonnais/GPS_IRVE.csv: ['r', 'accessibilite']
# Skipping data/karine-montferme/IRVE_SEIPC.csv for missing pivot ['id_pdc'], cols were ['id_station', 'nom_station', 'adresse_station', 'latitude', 'longitude', 'nom_porteur', 'type_charge', 'nbre_pdc', 'type_connecteur', 'date_maj', 'observations', 'source']
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 17 has no name. Using "r".
# DIFF for data/symielecvar-symielec/IRVE_MOUVELECVAR_20180629.csv: ['accessibilite']
# DIFF for data/mouvoise/IRVE_SE60_20170630.csv: ['accessibilite']
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 20 has no name. Using "u".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 21 has no name. Using "v".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 22 has no name. Using "w".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 23 has no name. Using "x".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 24 has no name. Using "y".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 25 has no name. Using "z".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 26 has no name. Using "aa".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 27 has no name. Using "bb".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 28 has no name. Using "cc".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 29 has no name. Using "dd".
# DIFF for data/mouvoise/IRVE_SE60_20180517.csv: ['aa', 'z', 'modele de borne', 'w', 'v', 'u', 'y', 'fabricant borne', 'téléphone', 'dd', 'x', 'bb', 'accessibilite', "modalité d'accès à la borne", 'cc']
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 20 has no name. Using "u".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 21 has no name. Using "v".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 22 has no name. Using "w".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 23 has no name. Using "x".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 24 has no name. Using "y".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 25 has no name. Using "z".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 26 has no name. Using "aa".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 27 has no name. Using "bb".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 28 has no name. Using "cc".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 29 has no name. Using "dd".
# DIFF for data/mouvoise/IRVE_SE60_20180716.csv: ['aa', 'z', 'modele de borne', 'w', 'v', 'u', 'y', 'fabricant borne', 'téléphone', 'dd', 'x', 'bb', 'accessibilite', "modalité d'accès à la borne", 'cc']
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 20 has no name. Using "u".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 21 has no name. Using "v".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 22 has no name. Using "w".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 23 has no name. Using "x".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 24 has no name. Using "y".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 25 has no name. Using "z".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 26 has no name. Using "aa".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 27 has no name. Using "bb".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 28 has no name. Using "cc".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 29 has no name. Using "dd".
# DIFF for data/mouvoise/IRVE_SE60_20180420.csv: ['aa', 'z', 'modele de borne', 'w', 'v', 'u', 'y', 'fabricant borne', 'téléphone', 'dd', 'x', 'bb', 'accessibilite', "modalité d'accès à la borne", 'cc']
# 	 CSV parse error: Row 0 has 2 values, but Table only has 1 columns.
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 20 has no name. Using "u".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 21 has no name. Using "v".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 22 has no name. Using "w".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 23 has no name. Using "x".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 24 has no name. Using "y".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 25 has no name. Using "z".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 26 has no name. Using "aa".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 27 has no name. Using "bb".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 28 has no name. Using "cc".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 29 has no name. Using "dd".
# DIFF for data/mouvoise/IRVE_SE60_20180816.csv: ['aa', 'z', 'modele de borne', 'w', 'v', 'u', 'y', 'fabricant borne', 'téléphone', 'dd', 'x', 'bb', 'accessibilite', "modalité d'accès à la borne", 'cc']
# DIFF for data/syndicat-intercommunal-denergie-dindre-et-loire-1/IRVE_SIEIL37_20170321.csv: ['accessibilite']
# DIFF for data/syndicat-departemental-denergie-de-saone-et-loire/IRVE_SYDESL_20180104.csv: ['accessibilitã©']
# Skipping data/data-gouv-fr/Stations-recharge-VE-ville-exemple.csv for missing pivot ['id_pdc'], cols were ['id_station', 'nom_station', 'adresse_station', 'latitude_wsg84', 'longitude_wsg84', 'nom_porteur', 'type_charge', 'nbre_pdc', 'type_connecteur', 'date_maj', 'observations', 'l', 'm', 'n', 'o']
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 11 has no name. Using "l".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 12 has no name. Using "m".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 13 has no name. Using "n".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 14 has no name. Using "o".
# DIFF for data/leonard-du-mas-de-paysac/IRVE_SIDELC_20180209.csv: ['accessibilite']
# DIFF for data/leonard-du-mas-de-paysac/IRVE_SYDEGO_20180226.csv: ['accessibilite']
# DIFF for data/leonard-du-mas-de-paysac/IRVE_Se61_20170306.csv: ['accessibilite']
# 	 CSV parse error: Row 0 has 12 values, but Table only has 1 columns.
# Skipping data/leonard-du-mas-de-paysac/IRVE_Se61_20180615.csv for missing pivot ['id_station'], cols were ['n_amenageur', 'n_operateur', 'n_enseigne', 'id_emi3_zone', 'libelle_affichable', 'ad_station', 'code_insee', 'xlongitude', 'ylatitude', 'nbre_pdc', 'id_pdc', 'puissance_max', 'type_prise', 'acces_recharge', 'accessibilite', 'observations', 'date_maj']
# Skipping data/ville-de-beauvais/IRVE_VILLEDEBEAUVAIS_20170320.csv for missing pivot ['id_station', 'id_pdc', 'date_maj'], cols were ['n_amenageur', '\tn_operateur', '\tn_enseigne', '\tid_station', '\tn_station', '\tad_station', '\tcode_insee', '\txlongitude', '\tylatitude', '\tnbre_pdc', '\tid_pdc', '\tpuiss_max', '\ttype_prise', '\tacces_recharge', 'accéssibilité', 'observation', '\tdate_maj']
# DIFF for data/alexandre-court-2/IRVE_SIMONE_20180528.csv: ['accessibilite']
# DIFF for data/alexandre-court-2/IRVE_MObiVE_20180625.csv: ['accessibilite']
# DIFF for data/alexandre-court-2/IRVE_Alize_Liberte_20180528.csv: ['accessibilite']
# DIFF for data/alexandre-court-2/IRVE_SIEML_20180528.csv: ['accessibilite']
# DIFF for data/alexandre-court-2/IRVE_Reveo_20180820.csv: ['accessibilite']
# DIFF for data/alexandre-court-2/IRVE_TEM53_20180528.csv: ['accessibilite']
# DIFF for data/alexandre-court-2/IRVE_SDE35_20180528.csv: ['accessibilite']
# DIFF for data/sydev/IRVE_SYDEV_20180502.csv: ['accessibilite']
# Done.

# %%
# use columns_mapping to build a database of unique stations based on (id_station, id_pdc, max(date_maj))

bornes = []

def find_by_pivot(row, lines):
    pass

def ifind_in_row_by_col(col, row):
    for key in row.keys():
        if col.lower() == key.lower():
            return row[key]

for child in [x for x in p.iterdir() if x.is_dir()]:
    csvs = list(child.glob('*.csv'))
    for csv in csvs:
        table = parse_csv(csv)
        if table:
            table_cols = [x.lower() for x in table.column_names]
            missing_pivot = []
            for pivot in ['id_station', 'id_pdc', 'date_maj']:
                if pivot not in table_cols:
                    missing_pivot.append(pivot)
            if missing_pivot:
                break
            for row in table.rows:
                borne = {}
                for col in columns_mapping:
                    for c in col:
                        if c.lower() in table_cols:
                            # use the standard name for column
                            borne[col[0]] = ifind_in_row_by_col(c, row)
                            break
                borne['source'] = str(csv)
                bornes.append(borne)
                
bornes
# Out:
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 0 has no name. Using "a".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 17 has no name. Using "r".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 18 has no name. Using "s".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 19 has no name. Using "t".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 20 has no name. Using "u".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 21 has no name. Using "v".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 22 has no name. Using "w".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 23 has no name. Using "x".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 11 has no name. Using "l".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 12 has no name. Using "m".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 13 has no name. Using "n".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 14 has no name. Using "o".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 17 has no name. Using "r".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 18 has no name. Using "s".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 19 has no name. Using "t".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 20 has no name. Using "u".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 21 has no name. Using "v".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 22 has no name. Using "w".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 23 has no name. Using "x".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 24 has no name. Using "y".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 25 has no name. Using "z".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 26 has no name. Using "aa".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 27 has no name. Using "bb".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 28 has no name. Using "cc".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 29 has no name. Using "dd".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 30 has no name. Using "ee".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 31 has no name. Using "ff".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 32 has no name. Using "gg".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 33 has no name. Using "hh".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 34 has no name. Using "ii".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 35 has no name. Using "jj".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 36 has no name. Using "kk".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 37 has no name. Using "ll".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 38 has no name. Using "mm".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 39 has no name. Using "nn".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 40 has no name. Using "oo".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 41 has no name. Using "pp".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 42 has no name. Using "qq".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 43 has no name. Using "rr".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 44 has no name. Using "ss".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 45 has no name. Using "tt".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 46 has no name. Using "uu".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 47 has no name. Using "vv".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 48 has no name. Using "ww".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 49 has no name. Using "xx".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 50 has no name. Using "yy".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 51 has no name. Using "zz".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 52 has no name. Using "aaa".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 53 has no name. Using "bbb".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 54 has no name. Using "ccc".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 55 has no name. Using "ddd".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 56 has no name. Using "eee".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 57 has no name. Using "fff".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 58 has no name. Using "ggg".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 59 has no name. Using "hhh".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 60 has no name. Using "iii".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 61 has no name. Using "jjj".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 62 has no name. Using "kkk".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 63 has no name. Using "lll".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 64 has no name. Using "mmm".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 65 has no name. Using "nnn".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 66 has no name. Using "ooo".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 67 has no name. Using "ppp".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 68 has no name. Using "qqq".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 69 has no name. Using "rrr".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 70 has no name. Using "sss".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 71 has no name. Using "ttt".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 72 has no name. Using "uuu".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 73 has no name. Using "vvv".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 74 has no name. Using "www".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 75 has no name. Using "xxx".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 76 has no name. Using "yyy".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 77 has no name. Using "zzz".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 78 has no name. Using "aaaa".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 79 has no name. Using "bbbb".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 80 has no name. Using "cccc".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 81 has no name. Using "dddd".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 82 has no name. Using "eeee".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 83 has no name. Using "ffff".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 84 has no name. Using "gggg".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 85 has no name. Using "hhhh".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 86 has no name. Using "iiii".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 87 has no name. Using "jjjj".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 88 has no name. Using "kkkk".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 89 has no name. Using "llll".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 90 has no name. Using "mmmm".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 91 has no name. Using "nnnn".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 92 has no name. Using "oooo".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 93 has no name. Using "pppp".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 94 has no name. Using "qqqq".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 95 has no name. Using "rrrr".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 96 has no name. Using "ssss".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 97 has no name. Using "tttt".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 98 has no name. Using "uuuu".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 99 has no name. Using "vvvv".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 100 has no name. Using "wwww".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 101 has no name. Using "xxxx".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 102 has no name. Using "yyyy".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 103 has no name. Using "zzzz".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 104 has no name. Using "aaaaa".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 105 has no name. Using "bbbbb".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 106 has no name. Using "ccccc".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 107 has no name. Using "ddddd".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 108 has no name. Using "eeeee".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 109 has no name. Using "fffff".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 110 has no name. Using "ggggg".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 111 has no name. Using "hhhhh".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 112 has no name. Using "iiiii".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 113 has no name. Using "jjjjj".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 114 has no name. Using "kkkkk".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 115 has no name. Using "lllll".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 116 has no name. Using "mmmmm".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 117 has no name. Using "nnnnn".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 118 has no name. Using "ooooo".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 119 has no name. Using "ppppp".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 120 has no name. Using "qqqqq".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 121 has no name. Using "rrrrr".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 122 has no name. Using "sssss".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 123 has no name. Using "ttttt".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 124 has no name. Using "uuuuu".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 125 has no name. Using "vvvvv".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 126 has no name. Using "wwwww".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 127 has no name. Using "xxxxx".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 128 has no name. Using "yyyyy".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 129 has no name. Using "zzzzz".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 130 has no name. Using "aaaaaa".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 131 has no name. Using "bbbbbb".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 132 has no name. Using "cccccc".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 133 has no name. Using "dddddd".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 134 has no name. Using "eeeeee".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 135 has no name. Using "ffffff".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 136 has no name. Using "gggggg".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 137 has no name. Using "hhhhhh".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 138 has no name. Using "iiiiii".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 139 has no name. Using "jjjjjj".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 140 has no name. Using "kkkkkk".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 141 has no name. Using "llllll".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 142 has no name. Using "mmmmmm".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 143 has no name. Using "nnnnnn".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 144 has no name. Using "oooooo".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 145 has no name. Using "pppppp".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 146 has no name. Using "qqqqqq".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 147 has no name. Using "rrrrrr".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 148 has no name. Using "ssssss".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 149 has no name. Using "tttttt".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 150 has no name. Using "uuuuuu".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 151 has no name. Using "vvvvvv".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 152 has no name. Using "wwwwww".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 153 has no name. Using "xxxxxx".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 17 has no name. Using "r".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 17 has no name. Using "r".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 17 has no name. Using "r".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 17 has no name. Using "r".
# 	 CSV parse error: Row 0 has 13 values, but Table only has 11 columns.
# 	 CSV parse error: Row 0 has 18 values, but Table only has 16 columns.
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 0 has no name. Using "a".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 1 has no name. Using "b".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 17 has no name. Using "r".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 18 has no name. Using "s".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 19 has no name. Using "t".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 20 has no name. Using "u".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 21 has no name. Using "v".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 22 has no name. Using "w".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 23 has no name. Using "x".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 24 has no name. Using "y".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 25 has no name. Using "z".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 17 has no name. Using "r".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 20 has no name. Using "u".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 21 has no name. Using "v".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 22 has no name. Using "w".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 23 has no name. Using "x".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 24 has no name. Using "y".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 25 has no name. Using "z".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 26 has no name. Using "aa".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 27 has no name. Using "bb".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 28 has no name. Using "cc".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 29 has no name. Using "dd".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 20 has no name. Using "u".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 21 has no name. Using "v".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 22 has no name. Using "w".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 23 has no name. Using "x".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 24 has no name. Using "y".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 25 has no name. Using "z".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 26 has no name. Using "aa".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 27 has no name. Using "bb".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 28 has no name. Using "cc".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 29 has no name. Using "dd".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 20 has no name. Using "u".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 21 has no name. Using "v".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 22 has no name. Using "w".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 23 has no name. Using "x".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 24 has no name. Using "y".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 25 has no name. Using "z".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 26 has no name. Using "aa".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 27 has no name. Using "bb".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 28 has no name. Using "cc".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 29 has no name. Using "dd".
# 	 CSV parse error: Row 0 has 2 values, but Table only has 1 columns.
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 20 has no name. Using "u".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 21 has no name. Using "v".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 22 has no name. Using "w".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 23 has no name. Using "x".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 24 has no name. Using "y".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 25 has no name. Using "z".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 26 has no name. Using "aa".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 27 has no name. Using "bb".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 28 has no name. Using "cc".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 29 has no name. Using "dd".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 11 has no name. Using "l".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 12 has no name. Using "m".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 13 has no name. Using "n".
# /opt/conda/lib/python3.6/site-packages/agate/utils.py:276: UnnamedColumnWarning: Column 14 has no name. Using "o".
# 	 CSV parse error: Row 0 has 12 values, but Table only has 1 columns.
# [{'Xlongitude': Decimal('0.007727'),
#   'Ylatitude': Decimal('43.187355'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 7/7',
#   'ad_station': 'Téléport 2 - D516 - 65290 Juillan',
#   'code_insee': Decimal('65235'),
#   'date_maj': '01/03/17',
#   'id_pdc': 'FR*S65*E65290*TELEP*01',
#   'id_station': 'FR*S65*P65290*TELEP',
#   'n_amenageur': 'SDE65',
#   'n_enseigne': 'Watt else?',
#   'n_operateur': 'SDE65',
#   'n_station': 'Téléport 2',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Badges du SDE65 à commander sur le site : www.sde-65.com/bienvenue/bornes-de-recharge-vehicules-electriques-ve/',
#   'puiss_max': Decimal('18'),
#   'source': 'data/serge-cieutat/IRVE_SDE65_20171020.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('0.007727'),
#   'Ylatitude': Decimal('43.187355'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 7/7',
#   'ad_station': 'Téléport 2 - D516 - 65290 Juillan',
#   'code_insee': Decimal('65235'),
#   'date_maj': '01/03/17',
#   'id_pdc': 'FR*S65*E65290*TELEP*02',
#   'id_station': 'FR*S65*P65290*TELEP',
#   'n_amenageur': 'SDE65',
#   'n_enseigne': 'Watt else?',
#   'n_operateur': 'SDE65',
#   'n_station': 'Téléport 2',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Badges du SDE65 à commander sur le site : www.sde-65.com/bienvenue/bornes-de-recharge-vehicules-electriques-ve/',
#   'puiss_max': Decimal('18'),
#   'source': 'data/serge-cieutat/IRVE_SDE65_20171020.csv',
#   'type_prise': 'E/F-T3'},
#  {'Xlongitude': Decimal('0.003208'),
#   'Ylatitude': Decimal('43.186965'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 7/7',
#   'ad_station': 'Aéroport Tarbes Lourdes Pyrénées - parking aéroport - 65290 Juillan',
#   'code_insee': Decimal('65235'),
#   'date_maj': '01/03/17',
#   'id_pdc': 'FR*S65*E65290*AERTLP*01',
#   'id_station': 'FR*S65*P65290*AERTLP',
#   'n_amenageur': 'SDE65',
#   'n_enseigne': 'Watt else?',
#   'n_operateur': 'SDE65',
#   'n_station': 'Aéroport TLP',
#   'nbre_pdc': Decimal('6'),
#   'observations': 'Badges du SDE65 à commander sur le site : www.sde-65.com/bienvenue/bornes-de-recharge-vehicules-electriques-ve/',
#   'puiss_max': Decimal('18'),
#   'source': 'data/serge-cieutat/IRVE_SDE65_20171020.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('0.003208'),
#   'Ylatitude': Decimal('43.186965'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 7/7',
#   'ad_station': 'Aéroport Tarbes Lourdes Pyrénées - parking aéroport - 65290 Juillan',
#   'code_insee': Decimal('65235'),
#   'date_maj': '01/03/17',
#   'id_pdc': 'FR*S65*E65290*AERTLP*02',
#   'id_station': 'FR*S65*P65290*AERTLP',
#   'n_amenageur': 'SDE65',
#   'n_enseigne': 'Watt else?',
#   'n_operateur': 'SDE65',
#   'n_station': 'Aéroport TLP',
#   'nbre_pdc': Decimal('6'),
#   'observations': 'Badges du SDE65 à commander sur le site : www.sde-65.com/bienvenue/bornes-de-recharge-vehicules-electriques-ve/',
#   'puiss_max': Decimal('18'),
#   'source': 'data/serge-cieutat/IRVE_SDE65_20171020.csv',
#   'type_prise': 'E/F-T3'},
#  {'Xlongitude': Decimal('0.003208'),
#   'Ylatitude': Decimal('43.186965'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 7/7',
#   'ad_station': 'Aéroport Tarbes Lourdes Pyrénées - parking aéroport - 65290 Juillan',
#   'code_insee': Decimal('65235'),
#   'date_maj': '01/03/17',
#   'id_pdc': 'FR*S65*E65290*AERTLP*03',
#   'id_station': 'FR*S65*P65290*AERTLP',
#   'n_amenageur': 'SDE65',
#   'n_enseigne': 'Watt else?',
#   'n_operateur': 'SDE65',
#   'n_station': 'Aéroport TLP',
#   'nbre_pdc': Decimal('6'),
#   'observations': 'Badges du SDE65 à commander sur le site : www.sde-65.com/bienvenue/bornes-de-recharge-vehicules-electriques-ve/',
#   'puiss_max': Decimal('7'),
#   'source': 'data/serge-cieutat/IRVE_SDE65_20171020.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('0.003208'),
#   'Ylatitude': Decimal('43.186965'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 7/7',
#   'ad_station': 'Aéroport Tarbes Lourdes Pyrénées - parking aéroport - 65290 Juillan',
#   'code_insee': Decimal('65235'),
#   'date_maj': '01/03/17',
#   'id_pdc': 'FR*S65*E65290*AERTLP*04',
#   'id_station': 'FR*S65*P65290*AERTLP',
#   'n_amenageur': 'SDE65',
#   'n_enseigne': 'Watt else?',
#   'n_operateur': 'SDE65',
#   'n_station': 'Aéroport TLP',
#   'nbre_pdc': Decimal('6'),
#   'observations': 'Badges du SDE65 à commander sur le site : www.sde-65.com/bienvenue/bornes-de-recharge-vehicules-electriques-ve/',
#   'puiss_max': Decimal('7'),
#   'source': 'data/serge-cieutat/IRVE_SDE65_20171020.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('0.003208'),
#   'Ylatitude': Decimal('43.186965'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 7/7',
#   'ad_station': 'Aéroport Tarbes Lourdes Pyrénées - parking aéroport - 65290 Juillan',
#   'code_insee': Decimal('65235'),
#   'date_maj': '01/03/17',
#   'id_pdc': 'FR*S65*E65290*AERTLP*05',
#   'id_station': 'FR*S65*P65290*AERTLP',
#   'n_amenageur': 'SDE65',
#   'n_enseigne': 'Watt else?',
#   'n_operateur': 'SDE65',
#   'n_station': 'Aéroport TLP',
#   'nbre_pdc': Decimal('6'),
#   'observations': 'Badges du SDE65 à commander sur le site : www.sde-65.com/bienvenue/bornes-de-recharge-vehicules-electriques-ve/',
#   'puiss_max': Decimal('7'),
#   'source': 'data/serge-cieutat/IRVE_SDE65_20171020.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('0.003208'),
#   'Ylatitude': Decimal('43.186965'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 7/7',
#   'ad_station': 'Aéroport Tarbes Lourdes Pyrénées - parking aéroport - 65290 Juillan',
#   'code_insee': Decimal('65235'),
#   'date_maj': '01/03/17',
#   'id_pdc': 'FR*S65*E65290*AERTLP*06',
#   'id_station': 'FR*S65*P65290*AERTLP',
#   'n_amenageur': 'SDE65',
#   'n_enseigne': 'Watt else?',
#   'n_operateur': 'SDE65',
#   'n_station': 'Aéroport TLP',
#   'nbre_pdc': Decimal('6'),
#   'observations': 'Badges du SDE65 à commander sur le site : www.sde-65.com/bienvenue/bornes-de-recharge-vehicules-electriques-ve/',
#   'puiss_max': Decimal('7'),
#   'source': 'data/serge-cieutat/IRVE_SDE65_20171020.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('-0.04229'),
#   'Ylatitude': Decimal('43.09965'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 7/7',
#   'ad_station': 'Avenue de la Gare - 65100 Lourdes',
#   'code_insee': Decimal('65286'),
#   'date_maj': '01/03/17',
#   'id_pdc': 'FR*S65*E65100*GARE*01',
#   'id_station': 'FR*S65*P65100*GARE',
#   'n_amenageur': 'SDE65',
#   'n_enseigne': 'Watt else?',
#   'n_operateur': 'SDE65',
#   'n_station': 'Gare',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Badges du SDE65 à commander sur le site : www.sde-65.com/bienvenue/bornes-de-recharge-vehicules-electriques-ve/',
#   'puiss_max': Decimal('18'),
#   'source': 'data/serge-cieutat/IRVE_SDE65_20171020.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('-0.04229'),
#   'Ylatitude': Decimal('43.09965'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 7/7',
#   'ad_station': 'Avenue de la Gare - 65100 Lourdes',
#   'code_insee': Decimal('65286'),
#   'date_maj': '01/03/17',
#   'id_pdc': 'FR*S65*E65100*GARE*02',
#   'id_station': 'FR*S65*P65100*GARE',
#   'n_amenageur': 'SDE65',
#   'n_enseigne': 'Watt else?',
#   'n_operateur': 'SDE65',
#   'n_station': 'Gare',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Badges du SDE65 à commander sur le site : www.sde-65.com/bienvenue/bornes-de-recharge-vehicules-electriques-ve/',
#   'puiss_max': Decimal('18'),
#   'source': 'data/serge-cieutat/IRVE_SDE65_20171020.csv',
#   'type_prise': 'E/F-T3'},
#  {'Xlongitude': Decimal('-0.05254'),
#   'Ylatitude': Decimal('43.09468'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 7/7',
#   'ad_station': 'Avenue du Paradis - 65100 Lourdes',
#   'code_insee': Decimal('65286'),
#   'date_maj': '01/03/17',
#   'id_pdc': 'FR*S65*E65100*PARAD*01',
#   'id_station': 'FR*S65*P65100*PARAD',
#   'n_amenageur': 'SDE65',
#   'n_enseigne': 'Watt else?',
#   'n_operateur': 'SDE65',
#   'n_station': 'paradis',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Badges du SDE65 à commander sur le site : www.sde-65.com/bienvenue/bornes-de-recharge-vehicules-electriques-ve/',
#   'puiss_max': Decimal('18'),
#   'source': 'data/serge-cieutat/IRVE_SDE65_20171020.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('-0.05254'),
#   'Ylatitude': Decimal('43.09468'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 7/7',
#   'ad_station': 'Avenue du Paradis - 65100 Lourdes',
#   'code_insee': Decimal('65286'),
#   'date_maj': '01/03/17',
#   'id_pdc': 'FR*S65*E65100*PARAD*02',
#   'id_station': 'FR*S65*P65100*PARAD',
#   'n_amenageur': 'SDE65',
#   'n_enseigne': 'Watt else?',
#   'n_operateur': 'SDE65',
#   'n_station': 'paradis',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Badges du SDE65 à commander sur le site : www.sde-65.com/bienvenue/bornes-de-recharge-vehicules-electriques-ve/',
#   'puiss_max': Decimal('18'),
#   'source': 'data/serge-cieutat/IRVE_SDE65_20171020.csv',
#   'type_prise': 'E/F-T3'},
#  {'Xlongitude': Decimal('-0.05541'),
#   'Ylatitude': Decimal('43.09586'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 7/7',
#   'ad_station': 'Parking Merlasse - Rue Sainte-Marie - 65100 Lourdes',
#   'code_insee': Decimal('65286'),
#   'date_maj': '01/03/17',
#   'id_pdc': 'FR*S65*E65100*MERLASSE*01',
#   'id_station': 'FR*S65*P65100*MERLASSE',
#   'n_amenageur': 'SDE65',
#   'n_enseigne': 'Watt else?',
#   'n_operateur': 'SDE65',
#   'n_station': 'merlasse',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Badges du SDE65 à commander sur le site : www.sde-65.com/bienvenue/bornes-de-recharge-vehicules-electriques-ve/',
#   'puiss_max': Decimal('18'),
#   'source': 'data/serge-cieutat/IRVE_SDE65_20171020.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('-0.05541'),
#   'Ylatitude': Decimal('43.09586'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 7/7',
#   'ad_station': 'Parking Merlasse - Rue Sainte-Marie - 65100 Lourdes',
#   'code_insee': Decimal('65286'),
#   'date_maj': '01/03/17',
#   'id_pdc': 'FR*S65*E65100*MERLASSE*02',
#   'id_station': 'FR*S65*P65100*MERLASSE',
#   'n_amenageur': 'SDE65',
#   'n_enseigne': 'Watt else?',
#   'n_operateur': 'SDE65',
#   'n_station': 'merlasse',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Badges du SDE65 à commander sur le site : www.sde-65.com/bienvenue/bornes-de-recharge-vehicules-electriques-ve/',
#   'puiss_max': Decimal('18'),
#   'source': 'data/serge-cieutat/IRVE_SDE65_20171020.csv',
#   'type_prise': 'E/F-T3'},
#  {'Xlongitude': Decimal('0.31975'),
#   'Ylatitude': Decimal('42.816583'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 7/7',
#   'ad_station': 'Parking du téléphérique - rue du Corps Franc Pommiès -65170  Saint-Lary-Soulan',
#   'code_insee': Decimal('65388'),
#   'date_maj': '01/03/17',
#   'id_pdc': 'FR*S65*E65170*TELEPHER*01',
#   'id_station': 'FR*S65*P65170*TELEPHER',
#   'n_amenageur': 'SDE65',
#   'n_enseigne': 'Watt else?',
#   'n_operateur': 'SDE65',
#   'n_station': 'Téléphérique',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Badges du SDE65 à commander sur le site : www.sde-65.com/bienvenue/bornes-de-recharge-vehicules-electriques-ve/',
#   'puiss_max': Decimal('18'),
#   'source': 'data/serge-cieutat/IRVE_SDE65_20171020.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('0.31975'),
#   'Ylatitude': Decimal('42.816583'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 7/7',
#   'ad_station': 'Parking du téléphérique - rue du Corps Franc Pommiès -65170  Saint-Lary-Soulan',
#   'code_insee': Decimal('65388'),
#   'date_maj': '01/03/17',
#   'id_pdc': 'FR*S65*E65170*TELEPHER*02',
#   'id_station': 'FR*S65*P65170*TELEPHER',
#   'n_amenageur': 'SDE65',
#   'n_enseigne': 'Watt else?',
#   'n_operateur': 'SDE65',
#   'n_station': 'Téléphérique',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Badges du SDE65 à commander sur le site : www.sde-65.com/bienvenue/bornes-de-recharge-vehicules-electriques-ve/',
#   'puiss_max': Decimal('18'),
#   'source': 'data/serge-cieutat/IRVE_SDE65_20171020.csv',
#   'type_prise': 'E/F-T3'},
#  {'Xlongitude': Decimal('0.323998'),
#   'Ylatitude': Decimal('42.817575'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 7/7',
#   'ad_station': 'Rue des Chardons - 65170 Saint-Lary-Soulan',
#   'code_insee': Decimal('65388'),
#   'date_maj': '01/03/17',
#   'id_pdc': 'FR*S65*E65170*CHARD*01',
#   'id_station': 'FR*S65*P65170*CHARD',
#   'n_amenageur': 'SDE65',
#   'n_enseigne': 'Watt else?',
#   'n_operateur': 'SDE65',
#   'n_station': 'Chardons',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Badges du SDE65 à commander sur le site : www.sde-65.com/bienvenue/bornes-de-recharge-vehicules-electriques-ve/',
#   'puiss_max': Decimal('18'),
#   'source': 'data/serge-cieutat/IRVE_SDE65_20171020.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('0.323998'),
#   'Ylatitude': Decimal('42.817575'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 7/7',
#   'ad_station': 'Rue des Chardons - 65170 Saint-Lary-Soulan',
#   'code_insee': Decimal('65388'),
#   'date_maj': '01/03/17',
#   'id_pdc': 'FR*S65*E65170*CHARD*02',
#   'id_station': 'FR*S65*P65170*CHARD',
#   'n_amenageur': 'SDE65',
#   'n_enseigne': 'Watt else?',
#   'n_operateur': 'SDE65',
#   'n_station': 'Chardons',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Badges du SDE65 à commander sur le site : www.sde-65.com/bienvenue/bornes-de-recharge-vehicules-electriques-ve/',
#   'puiss_max': Decimal('18'),
#   'source': 'data/serge-cieutat/IRVE_SDE65_20171020.csv',
#   'type_prise': 'E/F-T3'},
#  {'Xlongitude': Decimal('0.084079'),
#   'Ylatitude': Decimal('43.231565'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 7/7',
#   'ad_station': '23 Place Marcadieu 65000 Tarbes',
#   'code_insee': Decimal('65440'),
#   'date_maj': '01/03/17',
#   'id_pdc': 'FR*S65*E65000*MARCAD*01',
#   'id_station': 'FR*S65*P65000*MARCAD',
#   'n_amenageur': 'SDE65',
#   'n_enseigne': 'Watt else?',
#   'n_operateur': 'SDE65',
#   'n_station': 'marcadieu',
#   'nbre_pdc': Decimal('4'),
#   'observations': 'Badges du SDE65 à commander sur le site : www.sde-65.com/bienvenue/bornes-de-recharge-vehicules-electriques-ve/',
#   'puiss_max': Decimal('18'),
#   'source': 'data/serge-cieutat/IRVE_SDE65_20171020.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('0.084079'),
#   'Ylatitude': Decimal('43.231565'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 7/7',
#   'ad_station': '23 Place Marcadieu 65000 Tarbes',
#   'code_insee': Decimal('65440'),
#   'date_maj': '01/03/17',
#   'id_pdc': 'FR*S65*E65000*MARCAD*02',
#   'id_station': 'FR*S65*P65000*MARCAD',
#   'n_amenageur': 'SDE65',
#   'n_enseigne': 'Watt else?',
#   'n_operateur': 'SDE65',
#   'n_station': 'marcadieu',
#   'nbre_pdc': Decimal('4'),
#   'observations': 'Badges du SDE65 à commander sur le site : www.sde-65.com/bienvenue/bornes-de-recharge-vehicules-electriques-ve/',
#   'puiss_max': Decimal('18'),
#   'source': 'data/serge-cieutat/IRVE_SDE65_20171020.csv',
#   'type_prise': 'E/F-T3'},
#  {'Xlongitude': Decimal('0.084079'),
#   'Ylatitude': Decimal('43.231565'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 7/7',
#   'ad_station': '23 Place Marcadieu 65000 Tarbes',
#   'code_insee': Decimal('65440'),
#   'date_maj': '01/03/17',
#   'id_pdc': 'FR*S65*E65000*MARCAD*03',
#   'id_station': 'FR*S65*P65000*MARCAD',
#   'n_amenageur': 'SDE65',
#   'n_enseigne': 'Watt else?',
#   'n_operateur': 'SDE65',
#   'n_station': 'marcadieu',
#   'nbre_pdc': Decimal('4'),
#   'observations': 'Badges du SDE65 à commander sur le site : www.sde-65.com/bienvenue/bornes-de-recharge-vehicules-electriques-ve/',
#   'puiss_max': Decimal('18'),
#   'source': 'data/serge-cieutat/IRVE_SDE65_20171020.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('0.084079'),
#   'Ylatitude': Decimal('43.231565'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 7/7',
#   'ad_station': '23 Place Marcadieu 65000 Tarbes',
#   'code_insee': Decimal('65440'),
#   'date_maj': '01/03/17',
#   'id_pdc': 'FR*S65*E65000*MARCAD*04',
#   'id_station': 'FR*S65*P65000*MARCAD',
#   'n_amenageur': 'SDE65',
#   'n_enseigne': 'Watt else?',
#   'n_operateur': 'SDE65',
#   'n_station': 'marcadieu',
#   'nbre_pdc': Decimal('4'),
#   'observations': 'Badges du SDE65 à commander sur le site : www.sde-65.com/bienvenue/bornes-de-recharge-vehicules-electriques-ve/',
#   'puiss_max': Decimal('18'),
#   'source': 'data/serge-cieutat/IRVE_SDE65_20171020.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('0.074886'),
#   'Ylatitude': Decimal('43.231295'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 7/7',
#   'ad_station': 'Halle Brauhauban Rue Lamartine 65000 Tarbes',
#   'code_insee': Decimal('65440'),
#   'date_maj': '01/03/17',
#   'id_pdc': 'FR*S65*E65000*BRAUHAUBAN*01',
#   'id_station': 'FR*S65*P65000*BRAUHAUBAN',
#   'n_amenageur': 'SDE65',
#   'n_enseigne': 'Watt else?',
#   'n_operateur': 'SDE65',
#   'n_station': 'Brauhauban',
#   'nbre_pdc': Decimal('4'),
#   'observations': 'Badges du SDE65 à commander sur le site : www.sde-65.com/bienvenue/bornes-de-recharge-vehicules-electriques-ve/',
#   'puiss_max': Decimal('18'),
#   'source': 'data/serge-cieutat/IRVE_SDE65_20171020.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('0.074886'),
#   'Ylatitude': Decimal('43.231295'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 7/7',
#   'ad_station': 'Halle Brauhauban Rue Lamartine 65000 Tarbes',
#   'code_insee': Decimal('65440'),
#   'date_maj': '01/03/17',
#   'id_pdc': 'FR*S65*E65000*BRAUHAUBAN*02',
#   'id_station': 'FR*S65*P65000*BRAUHAUBAN',
#   'n_amenageur': 'SDE65',
#   'n_enseigne': 'Watt else?',
#   'n_operateur': 'SDE65',
#   'n_station': 'Brauhauban',
#   'nbre_pdc': Decimal('4'),
#   'observations': 'Badges du SDE65 à commander sur le site : www.sde-65.com/bienvenue/bornes-de-recharge-vehicules-electriques-ve/',
#   'puiss_max': Decimal('18'),
#   'source': 'data/serge-cieutat/IRVE_SDE65_20171020.csv',
#   'type_prise': 'E/F-T3'},
#  {'Xlongitude': Decimal('0.074886'),
#   'Ylatitude': Decimal('43.231295'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 7/7',
#   'ad_station': 'Halle Brauhauban Rue Lamartine 65000 Tarbes',
#   'code_insee': Decimal('65440'),
#   'date_maj': '01/03/17',
#   'id_pdc': 'FR*S65*E65000*BRAUHAUBAN*03',
#   'id_station': 'FR*S65*P65000*BRAUHAUBAN',
#   'n_amenageur': 'SDE65',
#   'n_enseigne': 'Watt else?',
#   'n_operateur': 'SDE65',
#   'n_station': 'Brauhauban',
#   'nbre_pdc': Decimal('4'),
#   'observations': 'Badges du SDE65 à commander sur le site : www.sde-65.com/bienvenue/bornes-de-recharge-vehicules-electriques-ve/',
#   'puiss_max': Decimal('18'),
#   'source': 'data/serge-cieutat/IRVE_SDE65_20171020.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('0.074886'),
#   'Ylatitude': Decimal('43.231295'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 7/7',
#   'ad_station': 'Halle Brauhauban Rue Lamartine 65000 Tarbes',
#   'code_insee': Decimal('65440'),
#   'date_maj': '01/03/17',
#   'id_pdc': 'FR*S65*E65000*BRAUHAUBAN*04',
#   'id_station': 'FR*S65*P65000*BRAUHAUBAN',
#   'n_amenageur': 'SDE65',
#   'n_enseigne': 'Watt else?',
#   'n_operateur': 'SDE65',
#   'n_station': 'Brauhauban',
#   'nbre_pdc': Decimal('4'),
#   'observations': 'Badges du SDE65 à commander sur le site : www.sde-65.com/bienvenue/bornes-de-recharge-vehicules-electriques-ve/',
#   'puiss_max': Decimal('18'),
#   'source': 'data/serge-cieutat/IRVE_SDE65_20171020.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('0.15511'),
#   'Ylatitude': Decimal('43.06825'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 7/7',
#   'ad_station': 'place du foirail - 65200 Bagnères-de-Bigorre',
#   'code_insee': Decimal('65059'),
#   'date_maj': '01/03/17',
#   'id_pdc': 'FR*S65*E65200*PLACEF*01',
#   'id_station': 'FR*S65*P65200*PLACEF',
#   'n_amenageur': 'SDE65',
#   'n_enseigne': 'Watt else?',
#   'n_operateur': 'SDE65',
#   'n_station': 'Foirail',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Badges du SDE65 à commander sur le site : www.sde-65.com/bienvenue/bornes-de-recharge-vehicules-electriques-ve/',
#   'puiss_max': Decimal('18'),
#   'source': 'data/serge-cieutat/IRVE_SDE65_20171020.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('0.15511'),
#   'Ylatitude': Decimal('43.06825'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 7/7',
#   'ad_station': 'place du foirail - 65200 Bagnères-de-Bigorre',
#   'code_insee': Decimal('65059'),
#   'date_maj': '01/03/17',
#   'id_pdc': 'FR*S65*E65200*PLACEF*02',
#   'id_station': 'FR*S65*P65200*PLACEF',
#   'n_amenageur': 'SDE65',
#   'n_enseigne': 'Watt else?',
#   'n_operateur': 'SDE65',
#   'n_station': 'Foirail',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Badges du SDE65 à commander sur le site : www.sde-65.com/bienvenue/bornes-de-recharge-vehicules-electriques-ve/',
#   'puiss_max': Decimal('18'),
#   'source': 'data/serge-cieutat/IRVE_SDE65_20171020.csv',
#   'type_prise': 'E/F-T3'},
#  {'Xlongitude': Decimal('0.14635'),
#   'Ylatitude': Decimal('43.062821'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 7/7',
#   'ad_station': 'place des thermes  - 65200 Bagnères-de-Bigorre',
#   'code_insee': Decimal('65059'),
#   'date_maj': '01/03/17',
#   'id_pdc': 'FR*S65*E65200*THERMES*01',
#   'id_station': 'FR*S65*P65200*THERMES',
#   'n_amenageur': 'SDE65',
#   'n_enseigne': 'Watt else?',
#   'n_operateur': 'SDE65',
#   'n_station': 'Thermes',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Badges du SDE65 à commander sur le site : www.sde-65.com/bienvenue/bornes-de-recharge-vehicules-electriques-ve/',
#   'puiss_max': Decimal('18'),
#   'source': 'data/serge-cieutat/IRVE_SDE65_20171020.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('0.14635'),
#   'Ylatitude': Decimal('43.062821'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 7/7',
#   'ad_station': 'place des thermes  - 65200 Bagnères-de-Bigorre',
#   'code_insee': Decimal('65059'),
#   'date_maj': '01/03/17',
#   'id_pdc': 'FR*S65*E65200*THERMES*02',
#   'id_station': 'FR*S65*P65200*THERMES',
#   'n_amenageur': 'SDE65',
#   'n_enseigne': 'Watt else?',
#   'n_operateur': 'SDE65',
#   'n_station': 'Thermes',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Badges du SDE65 à commander sur le site : www.sde-65.com/bienvenue/bornes-de-recharge-vehicules-electriques-ve/',
#   'puiss_max': Decimal('18'),
#   'source': 'data/serge-cieutat/IRVE_SDE65_20171020.csv',
#   'type_prise': 'E/F-T3'},
#  {'Xlongitude': Decimal('-0.047691'),
#   'Ylatitude': Decimal('43.093279'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 7/7',
#   'ad_station': 'place du champ commun - 65100 Lourdes',
#   'code_insee': Decimal('65286'),
#   'date_maj': '01/03/17',
#   'id_pdc': 'FR*S65*E65100*CHAMP*01',
#   'id_station': 'FR*S65*P65100*CHAMP',
#   'n_amenageur': 'SDE65',
#   'n_enseigne': 'Watt else?',
#   'n_operateur': 'SDE65',
#   'n_station': 'champ commun',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Badges du SDE65 à commander sur le site : www.sde-65.com/bienvenue/bornes-de-recharge-vehicules-electriques-ve/',
#   'puiss_max': Decimal('18'),
#   'source': 'data/serge-cieutat/IRVE_SDE65_20171020.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('-0.047691'),
#   'Ylatitude': Decimal('43.093279'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 7/7',
#   'ad_station': 'place du champ commun - 65100 Lourdes',
#   'code_insee': Decimal('65286'),
#   'date_maj': '01/03/17',
#   'id_pdc': 'FR*S65*E65100*CHAMP*02',
#   'id_station': 'FR*S65*P65100*CHAMP',
#   'n_amenageur': 'SDE65',
#   'n_enseigne': 'Watt else?',
#   'n_operateur': 'SDE65',
#   'n_station': 'champ commun',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Badges du SDE65 à commander sur le site : www.sde-65.com/bienvenue/bornes-de-recharge-vehicules-electriques-ve/',
# ...
#   'code_insee': Decimal('76382'),
#   'date_maj': datetime.date(2018, 4, 11),
#   'id_pdc': 'FR*SOD*E*SDE7*17*1*2*_',
#   'id_station': 'FR*SOD*P*SDE7*17*_*_*_',
#   'n_amenageur': 'SDE76',
#   'n_enseigne': 'SDE76',
#   'n_operateur': 'Sodetrel',
#   'n_station': 'LANQUETOT',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'RFID et application',
#   'puiss_max': Decimal('22'),
#   'source': 'data/aurelien-ouellette/IRVE_SDE76_20180411.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('1.436740'),
#   'Ylatitude': Decimal('50.006191'),
#   'acces_recharge': 'payant',
#   'accessibilité': datetime.date(2019, 7, 7),
#   'ad_station': 'Rue René Delcourt',
#   'code_insee': Decimal('76435'),
#   'date_maj': datetime.date(2018, 4, 11),
#   'id_pdc': 'FR*SOD*E*SDE7*35*1*1*_',
#   'id_station': 'FR*SOD*P*SDE7*35*_*_*_',
#   'n_amenageur': 'SDE76',
#   'n_enseigne': 'SDE76',
#   'n_operateur': 'Sodetrel',
#   'n_station': 'LE MESNIL REAUME',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'RFID et application',
#   'puiss_max': Decimal('22'),
#   'source': 'data/aurelien-ouellette/IRVE_SDE76_20180411.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('1.436740'),
#   'Ylatitude': Decimal('50.006191'),
#   'acces_recharge': 'payant',
#   'accessibilité': datetime.date(2019, 7, 7),
#   'ad_station': 'Rue René Delcourt',
#   'code_insee': Decimal('76435'),
#   'date_maj': datetime.date(2018, 4, 11),
#   'id_pdc': 'FR*SOD*E*SDE7*35*1*2*_',
#   'id_station': 'FR*SOD*P*SDE7*35*_*_*_',
#   'n_amenageur': 'SDE76',
#   'n_enseigne': 'SDE76',
#   'n_operateur': 'Sodetrel',
#   'n_station': 'LE MESNIL REAUME',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'RFID et application',
#   'puiss_max': Decimal('22'),
#   'source': 'data/aurelien-ouellette/IRVE_SDE76_20180411.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('0.202687'),
#   'Ylatitude': Decimal('49.684260'),
#   'acces_recharge': 'payant',
#   'accessibilité': datetime.date(2019, 7, 7),
#   'ad_station': 'Route du Havre',
#   'code_insee': Decimal('76693'),
#   'date_maj': datetime.date(2018, 4, 11),
#   'id_pdc': 'FR*SOD*E*SDE7*21*1*1*_',
#   'id_station': 'FR*SOD*P*SDE7*21*_*_*_',
#   'n_amenageur': 'SDE76',
#   'n_enseigne': 'SDE76',
#   'n_operateur': 'Sodetrel',
#   'n_station': 'LE TILLEUL',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'RFID et application',
#   'puiss_max': Decimal('22'),
#   'source': 'data/aurelien-ouellette/IRVE_SDE76_20180411.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('0.202687'),
#   'Ylatitude': Decimal('49.684260'),
#   'acces_recharge': 'payant',
#   'accessibilité': datetime.date(2019, 7, 7),
#   'ad_station': 'Route du Havre',
#   'code_insee': Decimal('76693'),
#   'date_maj': datetime.date(2018, 4, 11),
#   'id_pdc': 'FR*SOD*E*SDE7*21*1*2*_',
#   'id_station': 'FR*SOD*P*SDE7*21*_*_*_',
#   'n_amenageur': 'SDE76',
#   'n_enseigne': 'SDE76',
#   'n_operateur': 'Sodetrel',
#   'n_station': 'LE TILLEUL',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'RFID et application',
#   'puiss_max': Decimal('22'),
#   'source': 'data/aurelien-ouellette/IRVE_SDE76_20180411.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('1.228856'),
#   'Ylatitude': Decimal('49.785313'),
#   'acces_recharge': 'payant',
#   'accessibilité': datetime.date(2019, 7, 7),
#   'ad_station': "Place de l'Hôtel de ville",
#   'code_insee': Decimal('76321'),
#   'date_maj': datetime.date(2018, 4, 11),
#   'id_pdc': 'FR*SOD*E*SDE7*1*1*1*_',
#   'id_station': 'FR*SOD*P*SDE7*1*_*_*_',
#   'n_amenageur': 'SDE76',
#   'n_enseigne': 'SDE76',
#   'n_operateur': 'Sodetrel',
#   'n_station': 'LES GRANDES VENTES',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'RFID et application',
#   'puiss_max': Decimal('22'),
#   'source': 'data/aurelien-ouellette/IRVE_SDE76_20180411.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('1.228856'),
#   'Ylatitude': Decimal('49.785313'),
#   'acces_recharge': 'payant',
#   'accessibilité': datetime.date(2019, 7, 7),
#   'ad_station': "Place de l'Hôtel de ville",
#   'code_insee': Decimal('76321'),
#   'date_maj': datetime.date(2018, 4, 11),
#   'id_pdc': 'FR*SOD*E*SDE7*1*1*2*_',
#   'id_station': 'FR*SOD*P*SDE7*1*_*_*_',
#   'n_amenageur': 'SDE76',
#   'n_enseigne': 'SDE76',
#   'n_operateur': 'Sodetrel',
#   'n_station': 'LES GRANDES VENTES',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'RFID et application',
#   'puiss_max': Decimal('22'),
#   'source': 'data/aurelien-ouellette/IRVE_SDE76_20180411.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('0.202687'),
#   'Ylatitude': Decimal('49.684260'),
#   'acces_recharge': 'payant',
#   'accessibilité': datetime.date(2019, 7, 7),
#   'ad_station': 'Rue de la Gare',
#   'code_insee': Decimal('76390'),
#   'date_maj': datetime.date(2018, 4, 11),
#   'id_pdc': 'FR*SOD*E*SDE7*22*1*1*_',
#   'id_station': 'FR*SOD*P*SDE7*22*_*_*_',
#   'n_amenageur': 'SDE76',
#   'n_enseigne': 'SDE76',
#   'n_operateur': 'Sodetrel',
#   'n_station': 'LES LOGES - GARE',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'RFID et application',
#   'puiss_max': Decimal('22'),
#   'source': 'data/aurelien-ouellette/IRVE_SDE76_20180411.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('0.202687'),
#   'Ylatitude': Decimal('49.684260'),
#   'acces_recharge': 'payant',
#   'accessibilité': datetime.date(2019, 7, 7),
#   'ad_station': 'Rue de la Gare',
#   'code_insee': Decimal('76390'),
#   'date_maj': datetime.date(2018, 4, 11),
#   'id_pdc': 'FR*SOD*E*SDE7*22*1*2*_',
#   'id_station': 'FR*SOD*P*SDE7*22*_*_*_',
#   'n_amenageur': 'SDE76',
#   'n_enseigne': 'SDE76',
#   'n_operateur': 'Sodetrel',
#   'n_station': 'LES LOGES - GARE',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'RFID et application',
#   'puiss_max': Decimal('22'),
#   'source': 'data/aurelien-ouellette/IRVE_SDE76_20180411.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('0.202687'),
#   'Ylatitude': Decimal('49.684260'),
#   'acces_recharge': 'payant',
#   'accessibilité': datetime.date(2019, 7, 7),
#   'ad_station': 'Grande Rue',
#   'code_insee': Decimal('76390'),
#   'date_maj': datetime.date(2018, 4, 11),
#   'id_pdc': 'FR*SOD*E*SDE7*23*1*1*_',
#   'id_station': 'FR*SOD*P*SDE7*23*_*_*_',
#   'n_amenageur': 'SDE76',
#   'n_enseigne': 'SDE76',
#   'n_operateur': 'Sodetrel',
#   'n_station': 'LES LOGES - GRANDE RUE',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'RFID et application',
#   'puiss_max': Decimal('22'),
#   'source': 'data/aurelien-ouellette/IRVE_SDE76_20180411.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('0.202687'),
#   'Ylatitude': Decimal('49.684260'),
#   'acces_recharge': 'payant',
#   'accessibilité': datetime.date(2019, 7, 7),
#   'ad_station': 'Grande Rue',
#   'code_insee': Decimal('76390'),
#   'date_maj': datetime.date(2018, 4, 11),
#   'id_pdc': 'FR*SOD*E*SDE7*23*1*2*_',
#   'id_station': 'FR*SOD*P*SDE7*23*_*_*_',
#   'n_amenageur': 'SDE76',
#   'n_enseigne': 'SDE76',
#   'n_operateur': 'Sodetrel',
#   'n_station': 'LES LOGES - GRANDE RUE',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'RFID et application',
#   'puiss_max': Decimal('22'),
#   'source': 'data/aurelien-ouellette/IRVE_SDE76_20180411.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('1.403283'),
#   'Ylatitude': Decimal('49.830497'),
#   'acces_recharge': 'payant',
#   'accessibilité': datetime.date(2019, 7, 7),
#   'ad_station': 'Route de Neufchâtel',
#   'code_insee': Decimal('76392'),
#   'date_maj': datetime.date(2018, 4, 11),
#   'id_pdc': 'FR*SOD*E*SDE7*36*1*1*_',
#   'id_station': 'FR*SOD*P*SDE7*36*_*_*_',
#   'n_amenageur': 'SDE76',
#   'n_enseigne': 'SDE76',
#   'n_operateur': 'Sodetrel',
#   'n_station': 'LONDINIERES',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'RFID et application',
#   'puiss_max': Decimal('22'),
#   'source': 'data/aurelien-ouellette/IRVE_SDE76_20180411.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('1.403283'),
#   'Ylatitude': Decimal('49.830497'),
#   'acces_recharge': 'payant',
#   'accessibilité': datetime.date(2019, 7, 7),
#   'ad_station': 'Route de Neufchâtel',
#   'code_insee': Decimal('76392'),
#   'date_maj': datetime.date(2018, 4, 11),
#   'id_pdc': 'FR*SOD*E*SDE7*36*1*2*_',
#   'id_station': 'FR*SOD*P*SDE7*36*_*_*_',
#   'n_amenageur': 'SDE76',
#   'n_enseigne': 'SDE76',
#   'n_operateur': 'Sodetrel',
#   'n_station': 'LONDINIERES',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'RFID et application',
#   'puiss_max': Decimal('22'),
#   'source': 'data/aurelien-ouellette/IRVE_SDE76_20180411.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('1.51535833'),
#   'Ylatitude': Decimal('49.46383056'),
#   'acces_recharge': 'payant',
#   'accessibilité': datetime.date(2019, 7, 7),
#   'ad_station': 'IMPASSE DE L’EGLISE',
#   'code_insee': Decimal('76263'),
#   'date_maj': datetime.date(2018, 4, 11),
#   'id_pdc': 'FR*SOD*E*SDE7*71*1*1*_',
#   'id_station': 'FR*SOD*P*SDE7*71*_*_*_',
#   'n_amenageur': 'SDE76',
#   'n_enseigne': 'SDE76',
#   'n_operateur': 'Sodetrel',
#   'n_station': 'La Feuillie',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'RFID et application',
#   'puiss_max': Decimal('22'),
#   'source': 'data/aurelien-ouellette/IRVE_SDE76_20180411.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('1.51535833'),
#   'Ylatitude': Decimal('49.46383056'),
#   'acces_recharge': 'payant',
#   'accessibilité': datetime.date(2019, 7, 7),
#   'ad_station': 'IMPASSE DE L’EGLISE',
#   'code_insee': Decimal('76263'),
#   'date_maj': datetime.date(2018, 4, 11),
#   'id_pdc': 'FR*SOD*E*SDE7*71*1*2*_',
#   'id_station': 'FR*SOD*P*SDE7*71*_*_*_',
#   'n_amenageur': 'SDE76',
#   'n_enseigne': 'SDE76',
#   'n_operateur': 'Sodetrel',
#   'n_station': 'La Feuillie',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'RFID et application',
#   'puiss_max': Decimal('22'),
#   'source': 'data/aurelien-ouellette/IRVE_SDE76_20180411.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('0.411832'),
#   'Ylatitude': Decimal('49.528097'),
#   'acces_recharge': 'payant',
#   'accessibilité': datetime.date(2019, 7, 7),
#   'ad_station': 'Rue des Châtaigniers',
#   'code_insee': Decimal('76522'),
#   'date_maj': datetime.date(2018, 4, 11),
#   'id_pdc': 'FR*SOD*E*SDE7*7*1*1*_',
#   'id_station': 'FR*SOD*P*SDE7*7*_*_*_',
#   'n_amenageur': 'SDE76',
#   'n_enseigne': 'SDE76',
#   'n_operateur': 'Sodetrel',
#   'n_station': 'La Remuée',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'RFID et application',
#   'puiss_max': Decimal('22'),
#   'source': 'data/aurelien-ouellette/IRVE_SDE76_20180411.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('0.411832'),
#   'Ylatitude': Decimal('49.528097'),
#   'acces_recharge': 'payant',
#   'accessibilité': datetime.date(2019, 7, 7),
#   'ad_station': 'Rue des Châtaigniers',
#   'code_insee': Decimal('76522'),
#   'date_maj': datetime.date(2018, 4, 11),
#   'id_pdc': 'FR*SOD*E*SDE7*7*1*2*_',
#   'id_station': 'FR*SOD*P*SDE7*7*_*_*_',
#   'n_amenageur': 'SDE76',
#   'n_enseigne': 'SDE76',
#   'n_operateur': 'Sodetrel',
#   'n_station': 'La Remuée',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'RFID et application',
#   'puiss_max': Decimal('22'),
#   'source': 'data/aurelien-ouellette/IRVE_SDE76_20180411.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('1.00630278'),
#   'Ylatitude': Decimal('49.56324722'),
#   'acces_recharge': 'payant',
#   'accessibilité': datetime.date(2019, 7, 7),
#   'ad_station': 'route de Yerville',
#   'code_insee': Decimal('76385'),
#   'date_maj': datetime.date(2018, 4, 11),
#   'id_pdc': 'FR*SOD*E*SDE7*90*1*1*_',
#   'id_station': 'FR*SOD*P*SDE7*90*_*_*_',
#   'n_amenageur': 'SDE76',
#   'n_enseigne': 'SDE76',
#   'n_operateur': 'Sodetrel',
#   'n_station': 'Limésy',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'RFID et application',
#   'puiss_max': Decimal('22'),
#   'source': 'data/aurelien-ouellette/IRVE_SDE76_20180411.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('1.00630278'),
#   'Ylatitude': Decimal('49.56324722'),
#   'acces_recharge': 'payant',
#   'accessibilité': datetime.date(2019, 7, 7),
#   'ad_station': 'route de Yerville',
#   'code_insee': Decimal('76385'),
#   'date_maj': datetime.date(2018, 4, 11),
#   'id_pdc': 'FR*SOD*E*SDE7*90*1*2*_',
#   'id_station': 'FR*SOD*P*SDE7*90*_*_*_',
#   'n_amenageur': 'SDE76',
#   'n_enseigne': 'SDE76',
#   'n_operateur': 'Sodetrel',
#   'n_station': 'Limésy',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'RFID et application',
#   'puiss_max': Decimal('22'),
#   'source': 'data/aurelien-ouellette/IRVE_SDE76_20180411.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('1.172183'),
#   'Ylatitude': Decimal('49.814997'),
#   'acces_recharge': 'payant',
#   'accessibilité': datetime.date(2019, 7, 7),
#   'ad_station': '2 Bis rue du Général de Gaulle ',
#   'code_insee': Decimal('76397'),
#   'date_maj': datetime.date(2018, 4, 11),
#   'id_pdc': 'FR*SOD*E*SDE7*62*1*1*_',
#   'id_station': 'FR*SOD*P*SDE7*62*_*_*_',
#   'n_amenageur': 'SDE76',
#   'n_enseigne': 'SDE76',
#   'n_operateur': 'Sodetrel',
#   'n_station': 'Longueville-sur-Scie',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'RFID et application',
#   'puiss_max': Decimal('22'),
#   'source': 'data/aurelien-ouellette/IRVE_SDE76_20180411.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('1.172183'),
#   'Ylatitude': Decimal('49.814997'),
#   'acces_recharge': 'payant',
#   'accessibilité': datetime.date(2019, 7, 7),
#   'ad_station': '2 Bis rue du Général de Gaulle ',
#   'code_insee': Decimal('76397'),
#   'date_maj': datetime.date(2018, 4, 11),
#   'id_pdc': 'FR*SOD*E*SDE7*62*1*2*_',
#   'id_station': 'FR*SOD*P*SDE7*62*_*_*_',
#   'n_amenageur': 'SDE76',
#   'n_enseigne': 'SDE76',
#   'n_operateur': 'Sodetrel',
#   'n_station': 'Longueville-sur-Scie',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'RFID et application',
#   'puiss_max': Decimal('22'),
#   'source': 'data/aurelien-ouellette/IRVE_SDE76_20180411.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('0.91151111'),
#   'Ylatitude': Decimal('49.82804444'),
#   'acces_recharge': 'payant',
#   'accessibilité': datetime.date(2019, 7, 7),
#   'ad_station': 'Chemin des Hortensias',
#   'code_insee': Decimal('76400'),
#   'date_maj': datetime.date(2018, 4, 11),
#   'id_pdc': 'FR*SOD*E*SDE7*75*1*1*_',
#   'id_station': 'FR*SOD*P*SDE7*75*_*_*_',
#   'n_amenageur': 'SDE76',
#   'n_enseigne': 'SDE76',
#   'n_operateur': 'Sodetrel',
#   'n_station': 'Luneray',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'RFID et application',
#   'puiss_max': Decimal('22'),
#   'source': 'data/aurelien-ouellette/IRVE_SDE76_20180411.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('0.91151111'),
#   'Ylatitude': Decimal('49.82804444'),
#   'acces_recharge': 'payant',
#   'accessibilité': datetime.date(2019, 7, 7),
#   'ad_station': 'Chemin des Hortensias',
#   'code_insee': Decimal('76400'),
#   'date_maj': datetime.date(2018, 4, 11),
#   'id_pdc': 'FR*SOD*E*SDE7*75*1*2*_',
#   'id_station': 'FR*SOD*P*SDE7*75*_*_*_',
#   'n_amenageur': 'SDE76',
#   'n_enseigne': 'SDE76',
#   'n_operateur': 'Sodetrel',
#   'n_station': 'Luneray',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'RFID et application',
#   'puiss_max': Decimal('22'),
#   'source': 'data/aurelien-ouellette/IRVE_SDE76_20180411.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('0.255920'),
#   'Ylatitude': Decimal('49.565649'),
#   'acces_recharge': 'payant',
#   'accessibilité': datetime.date(2019, 7, 7),
#   'ad_station': 'Place de la Mairie',
#   'code_insee': Decimal('76404'),
#   'date_maj': datetime.date(2018, 4, 11),
#   'id_pdc': 'FR*SOD*E*SDE7*19*1*1*_',
#   'id_station': 'FR*SOD*P*SDE7*19*_*_*_',
#   'n_amenageur': 'SDE76',
#   'n_enseigne': 'SDE76',
#   'n_operateur': 'Sodetrel',
#   'n_station': 'MANEGLISE',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'RFID et application',
#   'puiss_max': Decimal('22'),
#   'source': 'data/aurelien-ouellette/IRVE_SDE76_20180411.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('0.255920'),
#   'Ylatitude': Decimal('49.565649'),
#   'acces_recharge': 'payant',
#   'accessibilité': datetime.date(2019, 7, 7),
#   'ad_station': 'Place de la Mairie',
#   'code_insee': Decimal('76404'),
#   'date_maj': datetime.date(2018, 4, 11),
#   'id_pdc': 'FR*SOD*E*SDE7*19*1*2*_',
#   'id_station': 'FR*SOD*P*SDE7*19*_*_*_',
#   'n_amenageur': 'SDE76',
#   'n_enseigne': 'SDE76',
#   'n_operateur': 'Sodetrel',
#   'n_station': 'MANEGLISE',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'RFID et application',
#   'puiss_max': Decimal('22'),
#   'source': 'data/aurelien-ouellette/IRVE_SDE76_20180411.csv',
#   'type_prise': 'E/F-T2'},
#  ...]

# %%
# deduplicate based on date_maj and id_pdc
from dateutil.parser import parse

unique_bornes = []

def parse_date(date):
    date = str(date)
    try:
        return parse(date)
    except ValueError:
        return parse('1970-1-1')

# filter out id_pdc==None
# TODO maybe use (id_station, id_pdc) instead of only id_pdc
ids = set([b['id_pdc'] for b in bornes if b['id_pdc']])
for _id in ids:
    bs = [b for b in bornes if b['id_pdc'] == _id]
    if len(bs) > 1:
        max_date = max([parse_date(b['date_maj']) for b in bs])
        unique = [b for b in bs if parse_date(b['date_maj']) == max_date][0]
    else:
        unique = bs[0]
    unique_bornes.append(unique)
    
unique_bornes
# Out:
# [{'Xlongitude': Decimal('6.64907300'),
#   'Ylatitude': Decimal('44.66132400'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24/24 7/7 jours',
#   'ad_station': 'Champ de Foire 05600 GUILLESTRE',
#   'code_insee': Decimal('5065'),
#   'date_maj': Decimal('20180905'),
#   'id_pdc': 'FR*S05*E05065*A*B1*D',
#   'id_station': 'FR*S05*P05065*A',
#   'n_amenageur': 'SYME05',
#   'n_enseigne': 'E Born',
#   'n_operateur': 'SYME05',
#   'n_station': 'GUILLESTRE_Champ de Foire',
#   'nbre_pdc': None,
#   'observations': None,
#   'puiss_max': Decimal('22.00'),
#   'source': 'data/gabrielle-caro/irve-syme05-20180905.csv',
#   'type_prise': 'E/F + T2'},
#  {'Xlongitude': Decimal('7165'),
#   'Ylatitude': Decimal('43225879'),
#   'acces_recharge': '2|3',
#   'accessibilité': 'Informations tarifaires disponibles sur le site de RÉVÉO : https://www.reveocharge.com/fr/comment-ca-marche/tarifs-de-recharge/',
#   'ad_station': 'Parking du SDE 65000 TARBES',
#   'code_insee': Decimal('65440'),
#   'date_maj': '20/08/2018',
#   'id_pdc': 'FR*S65*E65440*003*4',
#   'id_station': 'FR*S65*P65440*003',
#   'n_amenageur': 'SDE 65',
#   'n_enseigne': 'Révéo',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'TARBES - Parking du SDE',
#   'nbre_pdc': Decimal('4'),
#   'observations': 'Payant',
#   'puiss_max': Decimal('7'),
#   'source': 'data/alexandre-court-2/IRVE_Reveo_20180820.csv',
#   'type_prise': 'T2 - EF'},
#  {'Xlongitude': Decimal('3.298474'),
#   'Ylatitude': Decimal('49.840683'),
#   'acces_recharge': 'payant',
#   'accessibilité': 'accessible 24h/24 - 7j/7 ',
#   'ad_station': 'Place Andr� BAUDEZ 02100 SAINT QUENTIN',
#   'code_insee': Decimal('2691'),
#   'date_maj': datetime.date(2018, 8, 6),
#   'id_pdc': 'FR*S02*E026914A2',
#   'id_station': 'FR*S02*E026914A',
#   'n_amenageur': 'USEDA',
#   'n_enseigne': 'DIRVE 02',
#   'n_operateur': 'CITEOS-FRESHMILE',
#   'n_station': '0004 - GARE2 ',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'recharge normale et acc�l�r�e accessible par application smartphone/internet et badge - informations site web useda.fr -facturation en fonction de la puissance et du temps de charge',
#   'puiss_max': Decimal('22'),
#   'source': 'data/union-des-secteurs-denergie-du-departement-de-laisne/IRVE_USEDADIRVE02_20180806.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('5.14265200'),
#   'Ylatitude': Decimal('45.19498500'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24/24 7/7 jours',
#   'ad_station': 'Place du Lavoir 26350 ST BONNET DE VALCLERIEUX',
#   'code_insee': Decimal('26297'),
#   'date_maj': Decimal('20180905'),
#   'id_pdc': 'FR*S26*E26297*A*B1*G',
#   'id_station': 'FR*S26*P26297*A',
#   'n_amenageur': 'SDED',
#   'n_enseigne': 'E Born',
#   'n_operateur': 'SDED',
#   'n_station': 'ST BONNET DE VALCLERIEUX_Place du Lavoir',
#   'nbre_pdc': None,
#   'observations': None,
#   'puiss_max': Decimal('22.00'),
#   'source': 'data/gabrielle-caro/irve-sded-20180905.csv',
#   'type_prise': 'E/F + T2'},
#  {'Xlongitude': Decimal('33754065284'),
#   'Ylatitude': Decimal('476836448113'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 - 7/7',
#   'ad_station': '4 Grande rue - LEUGNY',
#   'code_insee': Decimal('89221'),
#   'date_maj': Decimal('20170519'),
#   'id_pdc': 'FR S89 E89221 A B1 G',
#   'id_station': 'FR S89 P89221 A',
#   'n_amenageur': "SDEY Syndicat Departemental d'Energies de l'Yonne",
#   'n_enseigne': None,
#   'n_operateur': 'SPIE',
#   'n_station': 'Place',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'En service',
#   'puiss_max': Decimal('22'),
#   'source': 'data/patrice-lozere/IRVE_SDEY_YONNE_20170519.csv',
#   'type_prise': 'T2 - E/F'},
#  {'Xlongitude': Decimal('0.53507'),
#   'Ylatitude': Decimal('46.81348'),
#   'acces_recharge': 'payant',
#   'accessibilité': '24/24 7/7 jours',
#   'ad_station': 'Rue Creuze - 86100 - Chatellerault',
#   'code_insee': Decimal('86066'),
#   'date_maj': '30/09/2017',
#   'id_pdc': 'FR*S86*ESORE*B023*2',
#   'id_station': 'FR*S86*PSORE*B023',
#   'n_amenageur': 'SOREGIES',
#   'n_enseigne': 'ALTERBASE86',
#   'n_operateur': 'SOREGIES',
#   'n_station': 'B023',
#   'nbre_pdc': Decimal('2'),
#   'observations': None,
#   'puiss_max': Decimal('18'),
#   'source': 'data/soregies/irve-soregies-20180831.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('3.852836'),
#   'Ylatitude': Decimal('48.501457'),
#   'acces_recharge': 'payant',
#   'ad_station': '1 Rue du Four 10510 CHATRES',
#   'code_insee': Decimal('10089'),
#   'date_maj': datetime.date(2018, 9, 4),
#   'id_pdc': 'FR*S10*E10089A2',
#   'id_station': 'FR*S10*P10089A',
#   'n_amenageur': 'SDEA10',
#   'n_enseigne': 'SDEA10',
#   'n_operateur': 'INEO TINEA',
#   'n_station': 'CHATRES',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Une unité = 6kWh de recharge. Utilisateur abonné : 1€/unité; Utilisateur occasionnel : 1,5€/unité',
#   'puiss_max': Decimal('18'),
#   'source': 'data/syndicat-departemental-denergie-de-laube-1/IRVE_SDEA_20180503.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('6.651370048522949'),
#   'Ylatitude': Decimal('44.65730285644531'),
#   'acces_recharge': 'payant',
#   'accessibilité': '24/24 7/7 jours',
#   'ad_station': ' 05600 GUILLESTRE (05)',
#   'code_insee': Decimal('5065'),
#   'date_maj': Decimal('43185'),
#   'id_pdc': 'FR*S05*P05065*C',
#   'id_station': 'FR*S05*P05065*C',
#   'n_amenageur': 'SyME05',
#   'n_enseigne': 'eborn',
#   'n_operateur': 'SyME05',
#   'n_station': 'Rue de la Fontloube ',
#   'nbre_pdc': '2',
#   'observations': "Abonné Eborn 10€/an/badge-24cts d'€ / kWh-non abonné-34 c d'€ / kWh-abonné flotte 35 € / mois/ badge plafonné à 500 kWh/mois puis charge à l'acte soit 24 c d'€ en charge accéléreé  ",
#   'puiss_max': '22',
#   'source': 'data/region-provence-alpes-cote-d-azur/bornes-recharge-agregation-region-reference.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('4.59880400'),
#   'Ylatitude': Decimal('44.73644300'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24/24 7/7 jours',
#   'ad_station': 'Place du Champs de Mars 07000 PRIVAS',
#   'code_insee': Decimal('7186'),
#   'date_maj': Decimal('20180905'),
#   'id_pdc': 'FR*S07*E07186*A*B1*D',
#   'id_station': 'FR*S07*P07186*A',
#   'n_amenageur': 'SDE07',
#   'n_enseigne': 'E Born',
#   'n_operateur': 'SDE07',
#   'n_station': 'PRIVAS_Place du Champs de Mars',
#   'nbre_pdc': None,
#   'observations': None,
#   'puiss_max': Decimal('22.00'),
#   'source': 'data/syndicat-departemental-denergies-de-lardeche/irve-sde07-20180905.csv',
#   'type_prise': 'E/F + T2'},
#  {'Xlongitude': Decimal('0.603436'),
#   'Ylatitude': Decimal('44.194826'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24h/24 et 7j/7',
#   'ad_station': 'Allée Du Luxembourg 47520 LE PASSAGE',
#   'code_insee': Decimal('47201'),
#   'date_maj': '25/06/2018',
#   'id_pdc': 'FR*S47*E47201*003*1',
#   'id_station': 'FR*S47*P47201*003',
#   'n_amenageur': 'SDEE 47',
#   'n_enseigne': 'MObiVE',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'LE PASSAGE - Allée Du Luxembourg',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Recharge par badge et avec une application smartphone',
#   'puiss_max': Decimal('18'),
#   'source': 'data/alexandre-court-2/IRVE_MObiVE_20180625.csv',
#   'type_prise': 'T2 - EF'},
#  {'Xlongitude': Decimal('-4.280022'),
#   'Ylatitude': Decimal('47.901928'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24/24_7/7',
#   'ad_station': 'Rue Ren� le Berre - 29174 Plon�our-Lanvern',
#   'code_insee': Decimal('29174'),
#   'date_maj': datetime.date(2018, 4, 4),
#   'id_pdc': 'FRS29ERQUP1',
#   'id_station': 'FRS29PSDE29ERQUP',
#   'n_amenageur': 'SDE29',
#   'n_enseigne': 'La borne �lectrique',
#   'n_operateur': 'Freshmile',
#   'n_station': 'Plon�our-Lanvern - Rue Ren� le Berre',
#   'nbre_pdc': Decimal('2'),
#   'observations': None,
#   'puiss_max': Decimal('22'),
#   'source': 'data/service-sig-sdef/IRVE_SDE29_20180404.csv',
#   'type_prise': 'T2-E/F'},
#  {'Xlongitude': Decimal('-1.0495252609'),
#   'Ylatitude': Decimal('43.7091865539'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24h/24 et 7j/7',
#   'ad_station': 'Place St Pierre 40100 DAX',
#   'code_insee': Decimal('40088'),
#   'date_maj': '25/06/2018',
#   'id_pdc': 'FR*S40*E40088*007*4',
#   'id_station': 'FR*S40*P40088*007',
#   'n_amenageur': 'SYDEC 40',
#   'n_enseigne': 'MObiVE',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'DAX - Place St Pierre',
#   'nbre_pdc': Decimal('4'),
#   'observations': 'Recharge par badge et avec une application smartphone',
#   'puiss_max': Decimal('4'),
#   'source': 'data/alexandre-court-2/IRVE_MObiVE_20180625.csv',
#   'type_prise': 'EF'},
#  {'Xlongitude': Decimal('0.681062'),
#   'Ylatitude': Decimal('44.23138'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24h/24 et 7j/7',
#   'ad_station': 'Parking Centre Bourg 47480 PONT-DU-CASSE',
#   'code_insee': Decimal('47209'),
#   'date_maj': '25/06/2018',
#   'id_pdc': 'FR*S47*E47209*001*1',
#   'id_station': 'FR*S47*P47209*001',
#   'n_amenageur': 'SDEE 47',
#   'n_enseigne': 'MObiVE',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'PONT-DU-CASSE - Parking Centre Bourg',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Recharge par badge et avec une application smartphone',
#   'puiss_max': Decimal('18'),
#   'source': 'data/alexandre-court-2/IRVE_MObiVE_20180625.csv',
#   'type_prise': 'T2 - EF'},
#  {'Xlongitude': Decimal('5.90845000'),
#   'Ylatitude': Decimal('44.90066000'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24/24 7/7 jours',
#   'ad_station': 'Rue Principale 38740 VALBONNAIS',
#   'code_insee': Decimal('38518'),
#   'date_maj': Decimal('20180905'),
#   'id_pdc': 'FR*S38*E38518*A*B1*G',
#   'id_station': 'FR*S38*P38518*A',
#   'n_amenageur': 'SEDI',
#   'n_enseigne': 'E Born',
#   'n_operateur': 'SEDI',
#   'n_station': 'VALBONNAIS_Rue Principale',
#   'nbre_pdc': None,
#   'observations': None,
#   'puiss_max': Decimal('22.00'),
#   'source': 'data/gabrielle-caro/irve-sedi-20180905.csv',
#   'type_prise': 'E/F + T2'},
#  {'Xlongitude': Decimal('194333'),
#   'Ylatitude': Decimal('4327'),
#   'acces_recharge': '2|3',
#   'accessibilité': 'Informations tarifaires disponibles sur le site de RÉVÉO : https://www.reveocharge.com/fr/comment-ca-marche/tarifs-de-recharge/',
#   'ad_station': 'Rue Prosper Estieu 11400 FENDEILLE',
#   'code_insee': Decimal('11138'),
#   'date_maj': '20/08/2018',
#   'id_pdc': 'FR*S11*E11138*001*2',
#   'id_station': 'FR*S11*P11138*001',
#   'n_amenageur': 'SYADEN 11',
#   'n_enseigne': 'Révéo',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'FENDEILLE - Rue Prosper Estieu',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Payant',
#   'puiss_max': Decimal('18'),
#   'source': 'data/alexandre-court-2/IRVE_Reveo_20180820.csv',
#   'type_prise': 'EF - T2'},
#  {'Xlongitude': Decimal('4380829'),
#   'Ylatitude': Decimal('44028009'),
#   'acces_recharge': '2|3',
#   'accessibilité': 'Informations tarifaires disponibles sur le site de RÉVÉO : https://www.reveocharge.com/fr/comment-ca-marche/tarifs-de-recharge/',
#   'ad_station': 'Parking Ecole 30700 MONTAREN SAINT MEDIERS',
#   'code_insee': Decimal('30174'),
#   'date_maj': '20/08/2018',
#   'id_pdc': 'FR*S30*E30174*001*2',
#   'id_station': 'FR*S30*P30174*001',
#   'n_amenageur': 'SMEG 30',
#   'n_enseigne': 'Révéo',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'MONTAREN SAINT MEDIERS - Parking Ecole',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Payant',
#   'puiss_max': Decimal('18'),
#   'source': 'data/alexandre-court-2/IRVE_Reveo_20180820.csv',
#   'type_prise': 'EF - T2 - T3'},
#  {'Xlongitude': Decimal('4.57977500'),
#   'Ylatitude': Decimal('44.98703300'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24/24 7/7 jours',
#   'ad_station': 'Place Predon 07270 LAMASTRE',
#   'code_insee': Decimal('7129'),
#   'date_maj': Decimal('20180905'),
#   'id_pdc': 'FR*S07*E07129*A*B1*G',
#   'id_station': 'FR*S07*P07129*A',
#   'n_amenageur': 'SDE07',
#   'n_enseigne': 'E Born',
#   'n_operateur': 'SDE07',
#   'n_station': 'LAMASTRE_Place Predon',
#   'nbre_pdc': None,
#   'observations': None,
#   'puiss_max': Decimal('50.00'),
#   'source': 'data/syndicat-departemental-denergies-de-lardeche/irve-sde07-20180905.csv',
#   'type_prise': 'CHAdeMO'},
#  {'Xlongitude': Decimal('1893346'),
#   'Ylatitude': Decimal('44858348'),
#   'acces_recharge': '2|3',
#   'accessibilité': 'Informations tarifaires disponibles sur le site de RÉVÉO : https://www.reveocharge.com/fr/comment-ca-marche/tarifs-de-recharge/',
#   'ad_station': 'Place de la république 46400 SAINT CERE',
#   'code_insee': Decimal('46251'),
#   'date_maj': '20/08/2018',
#   'id_pdc': 'FR*S46*E46251*001*2',
#   'id_station': 'FR*S46*P46251*001',
#   'n_amenageur': 'FDEL 46',
#   'n_enseigne': 'Révéo',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'SAINT CERE - Place de la république',
#   'nbre_pdc': Decimal('4'),
#   'observations': 'Payant',
#   'puiss_max': Decimal('36'),
#   'source': 'data/alexandre-court-2/IRVE_Reveo_20180820.csv',
#   'type_prise': 'CHADEMO'},
#  {'Xlongitude': Decimal('1975561'),
#   'Ylatitude': Decimal('43647542'),
#   'acces_recharge': '2|3',
#   'accessibilité': 'Informations tarifaires disponibles sur le site de RÉVÉO : https://www.reveocharge.com/fr/comment-ca-marche/tarifs-de-recharge/',
#   'ad_station': 'Place De La Resistance 81220 SAINT PAUL CAP DE JOUX',
#   'code_insee': Decimal('81266'),
#   'date_maj': '20/08/2018',
#   'id_pdc': 'FR*S81*E81266*001*2',
#   'id_station': 'FR*S81*P81266*001',
#   'n_amenageur': 'SDET 81',
#   'n_enseigne': 'Révéo',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'SAINT PAUL CAP DE JOUX - Place De La Resistance',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Payant',
#   'puiss_max': Decimal('18'),
#   'source': 'data/alexandre-court-2/IRVE_Reveo_20180820.csv',
#   'type_prise': 'EF - T2 - T3'},
#  {'Xlongitude': Decimal('-494282'),
#   'Ylatitude': Decimal('47468264'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24h/24 et 7j/7',
#   'ad_station': "Place Du Marché 49124 SAINT BARTHELEMY D'ANJOU",
#   'code_insee': Decimal('49267'),
#   'date_maj': '28/05/2018',
#   'id_pdc': 'FR*S49*E49267*001*2',
#   'id_station': 'FR*S49*P49267*001',
#   'n_amenageur': 'SIEML 49',
#   'n_enseigne': 'SIEML',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': "SAINT BARTHELEMY D'ANJOU - Place Du Marché",
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Recharge par badge et avec une application smartphone',
#   'puiss_max': Decimal('18'),
#   'source': 'data/alexandre-court-2/IRVE_SIEML_20180528.csv',
#   'type_prise': 'T2 - EF'},
#  {'Xlongitude': Decimal('1.22792'),
#   'Ylatitude': Decimal('43.5341'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24h/24 7j/7',
#   'ad_station': 'D632 31470 Fonsorbes',
#   'code_insee': Decimal('31187'),
#   'date_maj': datetime.date(2018, 3, 29),
#   'id_pdc': 'FR*S31*EGWUH*1',
#   'id_station': 'FR*S31*PUXRGDF',
#   'n_amenageur': 'SDEHG',
#   'n_enseigne': 'Roulez Électrique en Haute-Garonne',
#   'n_operateur': 'Freshmile',
#   'n_station': 'Fonsorbes, Intermarché',
#   'nbre_pdc': Decimal('2'),
#   'puiss_max': '18 kW',
#   'source': 'data/servane-macheto/IRVE_SDEHG_20180720.csv',
#   'type_prise': 'T2 - E/F'},
#  {'Xlongitude': '-0.593893',
#   'Ylatitude': Decimal('46.944964'),
#   'acces_recharge': 'payant',
#   'accessibilité': '24/24 7/7 jours',
#   'ad_station': ' avenue Saint Hubert - 79250 NUEIL LES AUBIERS',
#   'code_insee': Decimal('79195'),
#   'date_maj': '13/02/2017',
#   'id_pdc': 'FRSEOEAB73023A12',
#   'id_station': 'FRSEOPAB73023A',
#   'n_amenageur': 'S‚olis',
#   'n_enseigne': 'AlterBase',
#   'n_operateur': 'S‚olis',
#   'n_station': 'R‚seau Alterbase - Nueil les Aubiers - Espace Culturel Belle Arriv‚e',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'www.alterbase.fr',
#   'puiss_max': Decimal('3.18'),
#   'source': 'data/david-baufreton/IRVE_reseauAlterBase_20171116.CSV.csv',
#   'type_prise': 'E/F-T3'},
#  {'Xlongitude': Decimal('1081781'),
#   'Ylatitude': Decimal('44516632'),
#   'acces_recharge': '2|3',
#   'accessibilité': 'Informations tarifaires disponibles sur le site de RÉVÉO : https://www.reveocharge.com/fr/comment-ca-marche/tarifs-de-recharge/',
#   'ad_station': 'Place de la mairie 46700 DURAVEL',
#   'code_insee': Decimal('46089'),
#   'date_maj': '20/08/2018',
#   'id_pdc': 'FR*S46*E46089*001*2',
#   'id_station': 'FR*S46*P46089*001',
#   'n_amenageur': 'FDEL 46',
#   'n_enseigne': 'Révéo',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'DURAVEL - Place de la mairie',
#   'nbre_pdc': Decimal('4'),
#   'observations': 'Payant',
#   'puiss_max': Decimal('36'),
#   'source': 'data/alexandre-court-2/IRVE_Reveo_20180820.csv',
#   'type_prise': 'CHADEMO'},
#  {'Xlongitude': Decimal('2.99869'),
#   'Ylatitude': Decimal('49.5815'),
#   'acces_recharge': 'Gratuit',
#   'accessibilité': '24h/24 7j/7',
#   'ad_station': 'Place Aristide Briand 60400 Noyon',
#   'code_insee': Decimal('60471'),
#   'date_maj': '14/08/2018',
#   'id_pdc': 'FR*S60*EKNRW*1',
#   'id_station': 'FR*S60*PCFQLDZ',
#   'n_amenageur': 'SE60',
#   'n_enseigne': "Mouv'Oise ",
#   'n_operateur': 'Freshmile',
#   'n_station': 'Noyon, Place Aristide Briand',
#   'nbre_pdc': Decimal('2'),
#   'puiss_max': '22 kW',
#   'source': 'data/mouvoise/IRVE_SE60_20180816.csv',
#   'type_prise': 'T2 – E/F'},
#  {'Xlongitude': Decimal('4374356'),
#   'Ylatitude': Decimal('44000128'),
#   'acces_recharge': '2|3',
#   'accessibilité': 'Informations tarifaires disponibles sur le site de RÉVÉO : https://www.reveocharge.com/fr/comment-ca-marche/tarifs-de-recharge/',
#   'ad_station': 'Parking Pole Médical - Foyer" 30700 ARPAILLARGUES ET AUREILLAC"',
#   'code_insee': Decimal('30014'),
#   'date_maj': '20/08/2018',
#   'id_pdc': 'FR*S30*E30014*001*2',
#   'id_station': 'FR*S30*P30014*001',
#   'n_amenageur': 'SMEG 30',
#   'n_enseigne': 'Révéo',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'ARPAILLARGUES ET AUREILLAC - Parking Pole Médical - Foyer',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Payant',
#   'puiss_max': Decimal('18'),
#   'source': 'data/alexandre-court-2/IRVE_Reveo_20180820.csv',
#   'type_prise': 'EF - T2 - T3'},
#  {'Xlongitude': Decimal('-1.181364208459'),
#   'Ylatitude': Decimal('44.749343729'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24h/24 et 7j/7',
#   'ad_station': 'Avenue Des Halles - Claouey 33950 LEGE - CAP-FERRET',
#   'code_insee': Decimal('33236'),
#   'date_maj': '25/06/2018',
#   'id_pdc': 'FR*S33*E33236*002*1',
#   'id_station': 'FR*S33*P33236*002',
#   'n_amenageur': 'SDEEG 33',
#   'n_enseigne': 'MObiVE',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'LEGE - CAP-FERRET - Avenue Des Halles - Claouey',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Recharge par badge et avec une application smartphone',
#   'puiss_max': Decimal('18'),
#   'source': 'data/alexandre-court-2/IRVE_MObiVE_20180625.csv',
#   'type_prise': 'T2 - EF'},
#  {'Xlongitude': Decimal('3.458556'),
#   'Ylatitude': Decimal('49.796415'),
#   'acces_recharge': 'payant',
#   'accessibilité': 'accessible 24h/24 - 7j/7 ',
#   'ad_station': 'Place du Ch�teau 02240 RIBEMONT',
#   'code_insee': Decimal('2648'),
#   'date_maj': datetime.date(2018, 8, 6),
#   'id_pdc': 'FR*S02*E0264831A1',
#   'id_station': 'FR*S02*E0264831A',
#   'n_amenageur': 'USEDA',
#   'n_enseigne': 'DIRVE 02',
#   'n_operateur': 'CITEOS-FRESHMILE',
#   'n_station': '0031 - Place du ch�teau',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'recharge normale et acc�l�r�e accessible par application smartphone/internet et badge - informations site web useda.fr -facturation en fonction de la puissance et du temps de charge',
#   'puiss_max': Decimal('22'),
#   'source': 'data/union-des-secteurs-denergie-du-departement-de-laisne/IRVE_USEDADIRVE02_20180806.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('-3.545821'),
#   'Ylatitude': Decimal('47.874168'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24/24_7/7',
#   'ad_station': 'Place Barzaz Breizh - 29233 Quimperl�',
#   'code_insee': Decimal('29233'),
#   'date_maj': datetime.date(2018, 4, 4),
#   'id_pdc': 'FRS29ETFGQ2',
#   'id_station': 'FRS29PSDE29TFGQ',
#   'n_amenageur': 'SDE29',
#   'n_enseigne': 'La borne �lectrique',
#   'n_operateur': 'Freshmile',
#   'n_station': 'Quimperl� - Place Barzaz Breizh',
#   'nbre_pdc': Decimal('2'),
#   'observations': None,
#   'puiss_max': Decimal('22'),
#   'source': 'data/service-sig-sdef/IRVE_SDE29_20180404.csv',
#   'type_prise': 'T2-E/F'},
#  {'Xlongitude': Decimal('-876677'),
#   'Ylatitude': Decimal('47063467'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24h/24 et 7j/7',
#   'ad_station': 'Rue Docteur Charles Coignard 49300 CHOLET',
#   'code_insee': Decimal('49099'),
#   'date_maj': '28/05/2018',
#   'id_pdc': 'FR*S49*E49099*002*2',
#   'id_station': 'FR*S49*P49099*002',
#   'n_amenageur': 'SIEML 49',
#   'n_enseigne': 'SIEML',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'CHOLET - Rue Docteur Charles Coignard',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Recharge par badge et avec une application smartphone',
#   'puiss_max': Decimal('18'),
#   'source': 'data/alexandre-court-2/IRVE_SIEML_20180528.csv',
#   'type_prise': 'T2 - EF'},
#  {'Xlongitude': Decimal('2037937'),
#   'Ylatitude': Decimal('42457663'),
#   'acces_recharge': '2|3',
#   'accessibilité': 'Informations tarifaires disponibles sur le site de RÉVÉO : https://www.reveocharge.com/fr/comment-ca-marche/tarifs-de-recharge/',
#   'ad_station': 'Rue De  Sports 66800 SAILLAGOUSE',
#   'code_insee': Decimal('66167'),
#   'date_maj': '20/08/2018',
#   'id_pdc': 'FR*S66*E66167*001*1',
#   'id_station': 'FR*S66*P66167*001',
#   'n_amenageur': 'SYDEEL66 66',
#   'n_enseigne': 'Révéo',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'SAILLAGOUSE - Rue Des Sports',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Payant',
#   'puiss_max': Decimal('22'),
#   'source': 'data/alexandre-court-2/IRVE_Reveo_20180820.csv',
#   'type_prise': 'EF - T2 - T3'},
#  {'Xlongitude': '-0,15772504',
#   'Ylatitude': Decimal('4622664845'),
#   'acces_recharge': 'payant',
#   'accessibilité': '24/24 7/7 jours',
#   'ad_station': 'Lotissement le P‚rot - 79500 ST MARTIN LES MELLES',
#   'code_insee': Decimal('79279'),
#   'date_maj': '28/08/2017',
#   'id_pdc': 'FRSEOEAB58084A12',
#   'id_station': 'FRSEOPAB58084A',
#   'n_amenageur': 'S‚olis',
#   'n_enseigne': 'AlterBase',
#   'n_operateur': 'S‚olis',
#   'n_station': 'R‚seau Alterbase - St Martin les Melles -  Lotissement du P‚rot',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'www.alterbase.fr',
#   'puiss_max': Decimal('3.18'),
#   'source': 'data/david-baufreton/IRVE_reseauAlterBase_20171116.CSV.csv',
#   'type_prise': 'E/F-T3'},
#  {'Xlongitude': Decimal('3.15581360'),
#   'Ylatitude': Decimal('47.58124450'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24/24 7/7 jours',
#   'ad_station': 'Parking Ch?teau de Guedelon 89520 TREIGNY',
#   'code_insee': Decimal('89420'),
#   'date_maj': Decimal('20180905'),
#   'id_pdc': 'FR*S89*E89420*B*B1*G',
#   'id_station': 'FR*S89*P89420*B',
#   'n_amenageur': 'SDEY',
#   'n_enseigne': None,
#   'n_operateur': 'SDEY',
#   'n_station': 'TREIGNY_Parking Ch?teau de Guedelon',
#   'nbre_pdc': None,
#   'observations': None,
#   'puiss_max': Decimal('22.00'),
#   'source': 'data/gabrielle-caro/irve-sdey-20180905.csv',
#   'type_prise': 'E/F + T2'},
#  {'Xlongitude': Decimal('2176141'),
#   'Ylatitude': Decimal('43553589'),
#   'acces_recharge': '2|3',
#   'accessibilité': 'Informations tarifaires disponibles sur le site de RÉVÉO : https://www.reveocharge.com/fr/comment-ca-marche/tarifs-de-recharge/',
#   'ad_station': 'Place Du 8 Mai 1945 81290 VIVIERS LES MONTAGNES',
#   'code_insee': Decimal('81325'),
#   'date_maj': '20/08/2018',
#   'id_pdc': 'FR*S81*E81325*001*1',
#   'id_station': 'FR*S81*P81325*001',
#   'n_amenageur': 'SDET 81',
#   'n_enseigne': 'Révéo',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'VIVIERS LES MONTAGNES - Place Du 8 Mai 1945',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Payant',
#   'puiss_max': Decimal('22'),
#   'source': 'data/alexandre-court-2/IRVE_Reveo_20180820.csv',
#   'type_prise': 'EF - T2 - T3'},
#  {'Xlongitude': Decimal('0.665139'),
#   'Ylatitude': Decimal('47.350501'),
#   'acces_recharge': 'Payant',
#   'accessibilité': datetime.date(2019, 7, 7),
#   'ad_station': 'Rue des Martyrs - 37300 JOUE LES TOURS',
#   'code_insee': Decimal('37122'),
#   'date_maj': datetime.date(2017, 3, 21),
#   'id_pdc': 'FR*S37*E1252',
#   'id_station': None,
#   'n_amenageur': 'SIEIL37',
#   'n_enseigne': 'VIRTA',
#   'n_operateur': 'EneRSIEIL',
#   'n_station': 'JOUE LES TOURS 1252',
#   'nbre_pdc': True,
#   'observations': 'www.virtaev.fr',
#   'puiss_max': Decimal('18'),
#   'source': 'data/syndicat-intercommunal-denergie-dindre-et-loire-1/IRVE_SIEIL37_20170321.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('-0.02363'),
#   'Ylatitude': Decimal('47.10853'),
#   'acces_recharge': 'payant',
#   'accessibilité': '24/24 7/7 jours',
#   'ad_station': 'Rue de la Girouarirre - 86120 - Morton',
#   'code_insee': Decimal('86169'),
#   'date_maj': '31/03/2017',
#   'id_pdc': 'FR*S86*ESORE*B074*1',
#   'id_station': 'FR*S86*PSORE*B074',
#   'n_amenageur': 'SOREGIES',
#   'n_enseigne': 'ALTERBASE86',
#   'n_operateur': 'SOREGIES',
#   'n_station': 'B074',
#   'nbre_pdc': Decimal('2'),
#   'observations': None,
#   'puiss_max': Decimal('18'),
#   'source': 'data/soregies/irve-soregies-20180831.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('-124442'),
#   'Ylatitude': Decimal('47265602'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24h/24 et 7j/7',
#   'ad_station': 'Route de Saint Sauveur 49270 LANDEMONT',
#   'code_insee': Decimal('49172'),
#   'date_maj': '28/05/2018',
#   'id_pdc': 'FR*S49*E49172*001*2',
#   'id_station': 'FR*S49*P49172*001',
#   'n_amenageur': 'SIEML 49',
#   'n_enseigne': 'SIEML',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'LANDEMONT - Route de Saint Sauveur',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Recharge par badge et avec une application smartphone',
#   'puiss_max': Decimal('18'),
#   'source': 'data/alexandre-court-2/IRVE_SIEML_20180528.csv',
#   'type_prise': 'T2 - EF'},
#  {'Xlongitude': Decimal('-0.965542231138952'),
#   'Ylatitude': Decimal('44.63793013359816'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24h/24 et 7j/7',
#   'ad_station': 'Pei Gare 33380 BIGANOS',
#   'code_insee': Decimal('33051'),
#   'date_maj': '25/06/2018',
#   'id_pdc': 'FR*S33*E33051*002*2',
#   'id_station': 'FR*S33*P33051*002',
#   'n_amenageur': 'SDEEG 33',
#   'n_enseigne': 'MObiVE',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'BIGANOS - Pei Gare',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Recharge par badge et avec une application smartphone',
#   'puiss_max': Decimal('18'),
#   'source': 'data/alexandre-court-2/IRVE_MObiVE_20180625.csv',
#   'type_prise': 'T2 - EF'},
#  {'Xlongitude': Decimal('-3.843491'),
#   'Ylatitude': Decimal('48.575382'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24/24_7/7',
#   'ad_station': 'Place de la Mairie - 29254 Saint-Martin-des-Champs',
#   'code_insee': Decimal('29254'),
#   'date_maj': datetime.date(2018, 4, 4),
#   'id_pdc': 'FRS29EJCAW1',
#   'id_station': 'FRS29PSDE29JCAW',
#   'n_amenageur': 'SDE29',
#   'n_enseigne': 'La borne �lectrique',
#   'n_operateur': 'Freshmile',
#   'n_station': 'Saint-Martin-des-Champs - Place de la Mairie',
#   'nbre_pdc': Decimal('2'),
#   'observations': None,
#   'puiss_max': Decimal('22'),
#   'source': 'data/service-sig-sdef/IRVE_SDE29_20180404.csv',
#   'type_prise': 'T3-E/F'},
#  {'Xlongitude': Decimal('2920036'),
#   'Ylatitude': Decimal('42743605'),
#   'acces_recharge': '2|3',
#   'accessibilité': 'Informations tarifaires disponibles sur le site de RÉVÉO : https://www.reveocharge.com/fr/comment-ca-marche/tarifs-de-recharge/',
#   'ad_station': 'Rue Sainte Anne 66380 PIA',
#   'code_insee': Decimal('66141'),
#   'date_maj': '20/08/2018',
#   'id_pdc': 'FR*S66*E66141*001*2',
#   'id_station': 'FR*S66*P66141*001',
#   'n_amenageur': 'SYDEEL66 66',
#   'n_enseigne': 'Révéo',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'PIA - Rue Sainte Anne',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Payant',
#   'puiss_max': Decimal('22'),
#   'source': 'data/alexandre-court-2/IRVE_Reveo_20180820.csv',
#   'type_prise': 'EF - T2 - T3'},
#  {'Xlongitude': Decimal('4362859'),
#   'Ylatitude': Decimal('43817144'),
#   'acces_recharge': '2|3',
#   'accessibilité': 'Informations tarifaires disponibles sur le site de RÉVÉO : https://www.reveocharge.com/fr/comment-ca-marche/tarifs-de-recharge/',
#   'ad_station': 'Chemin Du Mas De Vignolles 30900 NIMES',
#   'code_insee': Decimal('30189'),
#   'date_maj': '20/08/2018',
#   'id_pdc': 'FR*S30*E30189*009*2',
#   'id_station': 'FR*S30*P30189*009',
#   'n_amenageur': 'SMEG 30',
#   'n_enseigne': 'Révéo',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'NIMES - Chemin Du Mas De Vignolles',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Payant',
#   'puiss_max': Decimal('18'),
#   'source': 'data/alexandre-court-2/IRVE_Reveo_20180820.csv',
#   'type_prise': 'EF - T2 - T3'},
#  {'Xlongitude': Decimal('0.896854'),
#   'Ylatitude': Decimal('49.669462'),
#   'acces_recharge': 'payant',
#   'accessibilité': datetime.date(2019, 7, 7),
#   'ad_station': 'Rue de la Liberté',
#   'code_insee': Decimal('76752'),
#   'date_maj': datetime.date(2018, 4, 11),
#   'id_pdc': 'FR*SOD*E*SDE7*12*1*2*_',
#   'id_station': 'FR*SOD*P*SDE7*12*_*_*_',
#   'n_amenageur': 'SDE76',
#   'n_enseigne': 'SDE76',
#   'n_operateur': 'Sodetrel',
#   'n_station': 'Yerville',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'RFID et application',
#   'puiss_max': Decimal('22'),
#   'source': 'data/aurelien-ouellette/IRVE_SDE76_20180411.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('1984011'),
#   'Ylatitude': Decimal('44221011'),
#   'acces_recharge': '2|3',
#   'accessibilité': 'Informations tarifaires disponibles sur le site de RÉVÉO : https://www.reveocharge.com/fr/comment-ca-marche/tarifs-de-recharge/',
#   'ad_station': 'Place Du Sol Del Barry - D39 12270 NAJAC',
#   'code_insee': Decimal('12167'),
#   'date_maj': '20/08/2018',
#   'id_pdc': 'FR*S12*E12167*001*1',
#   'id_station': 'FR*S12*P12167*001',
#   'n_amenageur': 'SIEDA 12',
#   'n_enseigne': 'Révéo',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'NAJAC - Place Du Sol Del Barry - D39',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Payant',
#   'puiss_max': Decimal('22'),
#   'source': 'data/alexandre-court-2/IRVE_Reveo_20180820.csv',
#   'type_prise': 'T2 - EF'},
#  {'Xlongitude': '-0,4604029',
#   'Ylatitude': Decimal('463288736'),
#   'acces_recharge': 'payant',
#   'accessibilité': '24/24 7/7 jours',
#   'ad_station': 'Place Chanzy - 79000 NIORT',
#   'code_insee': Decimal('79191'),
#   'date_maj': '18/07/2017',
#   'id_pdc': 'FRSEOEAB79191P0031A12',
#   'id_station': 'FRSEOPAB 79191P0031A',
#   'n_amenageur': 'S‚olis',
#   'n_enseigne': 'AlterBase',
#   'n_operateur': 'S‚olis',
#   'n_station': 'R‚seau Alterbase - Niort - Conseil D‚partemental 79',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'www.alterbase.fr',
#   'puiss_max': Decimal('3.18'),
#   'source': 'data/david-baufreton/IRVE_reseauAlterBase_20171116.CSV.csv',
#   'type_prise': 'E/F-T3'},
#  {'Xlongitude': Decimal('4.90853'),
#   'Ylatitude': Decimal('45.81920'),
#   'acces_recharge': '5€ / 45min, si abonné (10€/mois) : 1€/10min',
#   'accessibilité': '24h/24 7j/7',
#   'ad_station': "Avenue de l'Europe",
#   'code_insee': Decimal('69286'),
#   'date_maj': datetime.date(2018, 11, 4),
#   'id_pdc': 'FR*CN1*EUGPT*1',
#   'id_station': 'FR*CN1*P5899C629F2214',
#   'n_amenageur': 'CNR',
#   'n_enseigne': 'move in pure',
#   'n_operateur': 'Freshmile',
#   'n_station': 'Rilleux-la-Pape',
#   'nbre_pdc': Decimal('2'),
#   'puiss_max': Decimal('50'),
#   'source': 'data/cnr/IRVE_CNR_20180420.csv',
#   'type_prise': 'T2-Combo2-CHAdeMO'},
#  {'Xlongitude': Decimal('6.25013810'),
#   'Ylatitude': Decimal('46.19575040'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24/24 7/7 jours',
#   'ad_station': 'Rue de la Bruy?re 74100 ANNEMASSE',
#   'code_insee': Decimal('74012'),
#   'date_maj': Decimal('20180905'),
#   'id_pdc': 'FR*S74*E74012*C*B1*D',
#   'id_station': 'FR*S74*P74012*C',
#   'n_amenageur': 'SYANE',
#   'n_enseigne': 'E Born',
#   'n_operateur': 'SYANE',
#   'n_station': 'ANNEMASSE_Rue de la Bruy?re',
#   'nbre_pdc': None,
#   'observations': None,
#   'puiss_max': Decimal('22.00'),
#   'source': 'data/gabrielle-caro/irve-syane-20180905.csv',
#   'type_prise': 'E/F + T2'},
#  {'Xlongitude': Decimal('0.165742'),
#   'Ylatitude': Decimal('45.009018'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24h/24 et 7j/7',
#   'ad_station': 'Place Du Foirail 24700 MONTPON MENESTEROL',
#   'code_insee': Decimal('24294'),
#   'date_maj': '25/06/2018',
#   'id_pdc': 'FR*S24*E24294*002*2',
#   'id_station': 'FR*S24*P24294*002',
#   'n_amenageur': 'SDE 24',
#   'n_enseigne': 'MObiVE',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'MONTPON MENESTEROL - Place Du Foirail',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Recharge par badge et avec une application smartphone',
#   'puiss_max': Decimal('18'),
#   'source': 'data/alexandre-court-2/IRVE_MObiVE_20180625.csv',
#   'type_prise': 'T2 - EF'},
#  {'Xlongitude': Decimal('6.32492000'),
#   'Ylatitude': Decimal('46.36786000'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24/24 7/7 jours',
#   'ad_station': 'Parking Pr? Ponce 74140 YVOIRE',
#   'code_insee': Decimal('74315'),
#   'date_maj': Decimal('20180905'),
#   'id_pdc': 'FR*S74*E74315*A*B1*G',
#   'id_station': 'FR*S74*P74315*A',
#   'n_amenageur': 'SYANE',
#   'n_enseigne': 'E Born',
#   'n_operateur': 'SYANE',
#   'n_station': 'YVOIRE_Parking Pr? Ponce',
#   'nbre_pdc': None,
#   'observations': None,
#   'puiss_max': Decimal('22.00'),
#   'source': 'data/gabrielle-caro/irve-syane-20180905.csv',
#   'type_prise': 'E/F + T2'},
#  {'Xlongitude': Decimal('0.514153'),
#   'Ylatitude': Decimal('49.35304'),
#   'acces_recharge': 'payant',
#   'accessibilité': '24/24 7/7 jours',
#   'ad_station': 'Rue Delaquaize - annexe hopital Pont Audemer',
#   'code_insee': Decimal('27467'),
#   'date_maj': datetime.date(2017, 2, 10),
#   'id_pdc': 'FR*S27*EPTAUDEMER*ANNEXEHOPG',
#   'id_station': 'FR*S27*PPTAUDEMER*ANNEXEHOP',
#   'n_amenageur': 'SIEGE 27',
#   'n_enseigne': 'SIEGE 27',
#   'n_operateur': 'SIEGE 27',
#   'n_station': Decimal('900014'),
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Borne en service',
#   'puiss_max': Decimal('22.0'),
#   'source': 'data/christophe-gaillard/IRVE_SIEGE27_20171130.csv',
#   'type_prise': 'E/F-T3'},
#  {'Xlongitude': Decimal('1.224221'),
#   'Ylatitude': Decimal('49.275684'),
#   'acces_recharge': 'Pas en service',
#   'accessibilité': '24/24 7/7 jours',
#   'ad_station': 'Gare SNCF Val de Reuil',
#   'code_insee': Decimal('27701'),
#   'date_maj': datetime.date(2017, 2, 10),
#   'id_pdc': 'FR*S27*EVALREUIL*GARED',
#   'id_station': 'FR*S27*PVALREUIL*GARE',
#   'n_amenageur': 'SIEGE 27',
#   'n_enseigne': 'SIEGE 27',
#   'n_operateur': 'SIEGE 27',
#   'n_station': Decimal('900108'),
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Borne hors service',
#   'puiss_max': Decimal('22.0'),
#   'source': 'data/christophe-gaillard/IRVE_SIEGE27_20171130.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('0.083541'),
#   'Ylatitude': Decimal('44.650417'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24h/24 et 7j/7',
#   'ad_station': 'Place Du 8 Mai 33580 MONSEGUR',
#   'code_insee': Decimal('33289'),
#   'date_maj': '25/06/2018',
#   'id_pdc': 'FR*S33*E33289*001*2',
#   'id_station': 'FR*S33*P33289*001',
#   'n_amenageur': 'SDEEG 33',
#   'n_enseigne': 'MObiVE',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'MONSEGUR - Place Du 8 Mai',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Recharge par badge et avec une application smartphone',
#   'puiss_max': Decimal('18'),
#   'source': 'data/alexandre-court-2/IRVE_MObiVE_20180625.csv',
#   'type_prise': 'T2 - EF'},
#  {'Xlongitude': Decimal('37302'),
#   'Ylatitude': Decimal('4332151'),
#   'acces_recharge': '2|3',
#   'accessibilité': 'Informations tarifaires disponibles sur le site de RÉVÉO : https://www.reveocharge.com/fr/comment-ca-marche/tarifs-de-recharge/',
#   'ad_station': 'Rue de l’Abreuvoir 65220 TRIE SUR BAISE',
#   'code_insee': Decimal('65452'),
#   'date_maj': '20/08/2018',
#   'id_pdc': 'FR*S65*E65452*001*1',
#   'id_station': 'FR*S65*P65452*001',
#   'n_amenageur': 'SDE 65',
#   'n_enseigne': 'Révéo',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'TRIE SUR BAISE - Rue de l’Abreuvoir',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Payant',
#   'puiss_max': Decimal('18'),
#   'source': 'data/alexandre-court-2/IRVE_Reveo_20180820.csv',
#   'type_prise': 'T2 - EF'},
#  {'Xlongitude': Decimal('2.28562'),
#   'Ylatitude': Decimal('49.1781'),
#   'acces_recharge': 'Gratuit',
#   'accessibilité': '24h/24 7j/7',
#   'ad_station': '4 Avenue du Parc du Thelle 60530 Le Mesnil-en-Thelle',
#   'code_insee': Decimal('60398'),
#   'date_maj': '20/04/2018',
#   'id_pdc': 'FR*S60*EYJRB*2',
#   'id_station': 'FR*S60*PTHELLE',
#   'n_amenageur': 'SE60',
#   'n_enseigne': "Mouv'Oise ",
#   'n_operateur': 'Freshmile',
#   'n_station': 'Le Mesnil-en-Thelle, Parc du Thelle',
#   'nbre_pdc': Decimal('2'),
#   'puiss_max': '22 kW',
#   'source': 'data/mouvoise/IRVE_SE60_20180517.csv',
#   'type_prise': 'T2 – E/F'},
#  {'Xlongitude': Decimal('125007'),
#   'Ylatitude': Decimal('4752429'),
#   'acces_recharge': 'Payant',
#   'accessibilité': datetime.date(2019, 7, 7),
#   'ad_station': 'Route de la Champagne - 41150 Valloire-sur-Cisse',
#   'code_insee': Decimal('41055'),
#   'date_maj': Decimal('20180209'),
#   'id_pdc': 'FR*S41*E4884',
#   'id_station': 'FR*S41*P41055-87',
#   'n_amenageur': 'SIDELC',
#   'n_enseigne': 'VIRTA',
#   'n_operateur': 'EneRSIEIL',
#   'n_station': 'Valloire-sur-Cisse - 4884',
#   'nbre_pdc': True,
#   'observations': 'www.virtaev.fr',
#   'puiss_max': Decimal('18'),
#   'source': 'data/leonard-du-mas-de-paysac/IRVE_SIDELC_20180209.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('-11261'),
#   'Ylatitude': Decimal('428894'),
#   'acces_recharge': '2|3',
#   'accessibilité': 'Informations tarifaires disponibles sur le site de RÉVÉO : https://www.reveocharge.com/fr/comment-ca-marche/tarifs-de-recharge/',
#   'ad_station': 'Thermes. rue du docteur Domer 65110 CAUTERET',
#   'code_insee': Decimal('65138'),
#   'date_maj': '20/08/2018',
#   'id_pdc': 'FR*S65*E65138*002*1',
#   'id_station': 'FR*S65*P65138*002',
#   'n_amenageur': 'SDE 65',
#   'n_enseigne': 'Révéo',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'CAUTERET - Thermes',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Payant',
#   'puiss_max': Decimal('18'),
#   'source': 'data/alexandre-court-2/IRVE_Reveo_20180820.csv',
#   'type_prise': 'T2 - EF'},
#  {'Xlongitude': Decimal('-0.043265704433803'),
#   'Ylatitude': Decimal('44.85247716404577'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24h/24 et 7j/7',
#   'ad_station': 'Eglise 33350 CASTILLON-LA-BATAILLE',
#   'code_insee': Decimal('33108'),
#   'date_maj': '25/06/2018',
#   'id_pdc': 'FR*S33*E33108*001*2',
#   'id_station': 'FR*S33*P33108*001',
#   'n_amenageur': 'SDEEG 33',
#   'n_enseigne': 'MObiVE',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'CASTILLON-LA-BATAILLE - Eglise',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Recharge par badge et avec une application smartphone',
#   'puiss_max': Decimal('18'),
#   'source': 'data/alexandre-court-2/IRVE_MObiVE_20180625.csv',
#   'type_prise': 'T2 - EF'},
#  {'Xlongitude': Decimal('3326242243'),
#   'Ylatitude': Decimal('4937759236'),
#   'acces_recharge': 'payant',
#   'accessibilité': 'accessible 24h/24 - 7j/7 ',
#   'ad_station': 'Place dauphine 02200 SOISSONS',
#   'code_insee': Decimal('2722'),
#   'date_maj': datetime.date(2017, 1, 20),
#   'id_pdc': 'FR*S02*E0272236A',
#   'id_station': 'FR*S02*P0272236',
#   'n_amenageur': 'USEDA',
#   'n_enseigne': 'DIRVE 02',
#   'n_operateur': 'CITEOS-FRESHMILE',
#   'n_station': '0036 - Place Dauphine',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'recharge normale et accélérée accessible par application smartphone/internet et badge - informations site web useda.fr -facturation en fonction de la puissance et du temps de charge',
#   'puiss_max': Decimal('22'),
#   'source': 'data/union-des-secteurs-denergie-du-departement-de-laisne/IRVE_USEDADIRVE02_20170120.csv',
#   'type_prise': 'EF-T2'},
#  {'Xlongitude': Decimal('0.00135'),
#   'Ylatitude': Decimal('43.23392'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 7/7',
#   'ad_station': 'place de Verdun - 65420 Ibos',
#   'code_insee': Decimal('65226'),
#   'date_maj': '10/08/17',
#   'id_pdc': 'FR*S65*E65420*VERDUN*01',
#   'id_station': 'FR*S65*P65420*VERDUN',
#   'n_amenageur': 'SDE65',
#   'n_enseigne': 'Watt else?',
#   'n_operateur': 'SDE65',
#   'n_station': 'Verdun',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Badges du SDE65 à commander sur le site : www.sde-65.com/bienvenue/bornes-de-recharge-vehicules-electriques-ve/',
#   'puiss_max': Decimal('18'),
#   'source': 'data/serge-cieutat/IRVE_SDE65_20171020.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('-1.0749676823'),
#   'Ylatitude': Decimal('44.977233638'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24h/24 et 7j/7',
#   'ad_station': 'Rue Du Maréchal Leclerc 33680 LACANAU',
#   'code_insee': Decimal('33214'),
#   'date_maj': '25/06/2018',
#   'id_pdc': 'FR*S33*E33214*001*2',
#   'id_station': 'FR*S33*P33214*001',
#   'n_amenageur': 'SDEEG 33',
#   'n_enseigne': 'MObiVE',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'LACANAU - Rue Du Maréchal Leclerc',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Recharge par badge et avec une application smartphone',
#   'puiss_max': Decimal('18'),
#   'source': 'data/alexandre-court-2/IRVE_MObiVE_20180625.csv',
#   'type_prise': 'T2 - EF'},
#  {'Xlongitude': Decimal('-760868'),
#   'Ylatitude': Decimal('47348772'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24h/24 et 7j/7',
#   'ad_station': 'Rue Des Tonneliers 49290 CHALONNES SUR LOIRE',
#   'code_insee': Decimal('49063'),
#   'date_maj': '28/05/2018',
#   'id_pdc': 'FR*S49*E49063*001*2',
#   'id_station': 'FR*S49*P49063*001',
#   'n_amenageur': 'SIEML 49',
#   'n_enseigne': 'SIEML',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'CHALONNES SUR LOIRE - Rue Des Tonneliers',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Recharge par badge et avec une application smartphone',
#   'puiss_max': Decimal('18'),
#   'source': 'data/alexandre-court-2/IRVE_SIEML_20180528.csv',
#   'type_prise': 'T2 - EF'},
#  {'Xlongitude': Decimal('0.05075'),
#   'Ylatitude': Decimal('46.56231'),
#   'acces_recharge': 'payant',
#   'accessibilité': '24/24 7/7 jours',
#   'ad_station': 'Place de la salle des fetes - 86470 - Benassay',
#   'code_insee': Decimal('86021'),
#   'date_maj': '31/01/2017',
#   'id_pdc': 'FR*S86*ESORE*B007*2',
#   'id_station': 'FR*S86*PSORE*B007',
#   'n_amenageur': 'SOREGIES',
#   'n_enseigne': 'ALTERBASE86',
#   'n_operateur': 'SOREGIES',
#   'n_station': 'B007',
#   'nbre_pdc': Decimal('2'),
#   'observations': None,
#   'puiss_max': Decimal('18'),
#   'source': 'data/soregies/irve-soregies-20180831.csv',
#   'type_prise': 'E/F-T3'},
#  {'Xlongitude': Decimal('4051491'),
#   'Ylatitude': Decimal('44017089'),
#   'acces_recharge': '2|3',
#   'accessibilité': 'Informations tarifaires disponibles sur le site de RÉVÉO : https://www.reveocharge.com/fr/comment-ca-marche/tarifs-de-recharge/',
#   'ad_station': 'Allée De La Gare 30350 LEZAN',
#   'code_insee': Decimal('30147'),
#   'date_maj': '20/08/2018',
#   'id_pdc': 'FR*S30*E30147*001*1',
#   'id_station': 'FR*S30*P30147*001',
#   'n_amenageur': 'SMEG 30',
#   'n_enseigne': 'Révéo',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'LEZAN - Allée De La Gare',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Payant',
#   'puiss_max': Decimal('18'),
#   'source': 'data/alexandre-court-2/IRVE_Reveo_20180820.csv',
#   'type_prise': 'EF - T2 - T3'},
#  {'Xlongitude': Decimal('0.527887'),
#   'Ylatitude': Decimal('49.584935'),
#   'acces_recharge': 'payant',
#   'accessibilité': datetime.date(2019, 7, 7),
#   'ad_station': 'Route de Bolbec',
#   'code_insee': Decimal('76090'),
#   'date_maj': datetime.date(2018, 4, 11),
#   'id_pdc': 'FR*SOD*E*SDE7*43*1*2*_',
#   'id_station': 'FR*SOD*P*SDE7*43*_*_*_',
#   'n_amenageur': 'SDE76',
#   'n_enseigne': 'SDE76',
#   'n_operateur': 'Sodetrel',
#   'n_station': 'Beuzeville la Grenier',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'RFID et application',
#   'puiss_max': Decimal('22'),
#   'source': 'data/aurelien-ouellette/IRVE_SDE76_20180411.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('0.669544'),
#   'Ylatitude': Decimal('45.591543'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24h/24 et 7j/7',
#   'ad_station': 'Parking Du Roc Branlant 24360 SAINT ESTEPHE',
#   'code_insee': Decimal('24398'),
#   'date_maj': '25/06/2018',
#   'id_pdc': 'FR*S24*E24398*001*2',
#   'id_station': 'FR*S24*P24398*001',
#   'n_amenageur': 'SDE 24',
#   'n_enseigne': 'MObiVE',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'SAINT ESTEPHE - Parking Du Roc Branlant',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Recharge par badge et avec une application smartphone',
#   'puiss_max': Decimal('18'),
#   'source': 'data/alexandre-court-2/IRVE_MObiVE_20180625.csv',
#   'type_prise': 'T2 - EF'},
#  {'Xlongitude': Decimal('3.633996'),
#   'Ylatitude': Decimal('49.570061'),
#   'acces_recharge': 'payant',
#   'accessibilité': 'accessible 24h/24 - 7j/7 ',
#   'ad_station': 'Place Victor HUGO 02000 LAON',
#   'code_insee': Decimal('2408'),
#   'date_maj': datetime.date(2018, 8, 6),
#   'id_pdc': 'FR*S02*E0240827A1',
#   'id_station': 'FR*S02*E0240827A',
#   'n_amenageur': 'USEDA',
#   'n_enseigne': 'DIRVE 02',
#   'n_operateur': 'CITEOS-FRESHMILE',
#   'n_station': '0027 - Place Victor Hugo',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'recharge normale et acc�l�r�e accessible par application smartphone/internet et badge - informations site web useda.fr -facturation en fonction de la puissance et du temps de charge',
#   'puiss_max': Decimal('22'),
#   'source': 'data/union-des-secteurs-denergie-du-departement-de-laisne/IRVE_USEDADIRVE02_20180806.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('0.787667'),
#   'Ylatitude': Decimal('47.140961'),
#   'acces_recharge': 'Payant',
#   'accessibilité': datetime.date(2019, 7, 7),
#   'ad_station': 'Aire de co-voiturage RD50 - 37240 MANTHELAN',
#   'code_insee': Decimal('37143'),
#   'date_maj': datetime.date(2017, 3, 21),
#   'id_pdc': 'FR*S37*E1279',
#   'id_station': None,
#   'n_amenageur': 'SIEIL37',
#   'n_enseigne': 'VIRTA',
#   'n_operateur': 'EneRSIEIL',
#   'n_station': 'MANTHELAN 1279',
#   'nbre_pdc': True,
#   'observations': 'www.virtaev.fr',
#   'puiss_max': Decimal('18'),
#   'source': 'data/syndicat-intercommunal-denergie-dindre-et-loire-1/IRVE_SIEIL37_20170321.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('5.76524700'),
#   'Ylatitude': Decimal('43.78668700'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24/24 7/7 jours',
#   'ad_station': 'Place du Th?atre 04220 STE TULLE',
#   'code_insee': Decimal('4197'),
#   'date_maj': Decimal('20180329'),
#   'id_pdc': 'FR*S04*E04197*A*B1*G',
#   'id_station': 'FR*S04*P04197*A',
#   'n_amenageur': 'SDE04',
#   'n_enseigne': None,
#   'n_operateur': 'SDE04',
#   'n_station': 'STE TULLE_Place du Th?atre',
#   'nbre_pdc': '1',
#   'observations': None,
#   'puiss_max': '22',
#   'source': 'data/region-provence-alpes-cote-d-azur/bornes-recharge-agregation-region-reference.csv',
#   'type_prise': 'E/F + T2'},
#  {'Xlongitude': Decimal('-1.674989'),
#   'Ylatitude': Decimal('47.667198'),
#   'acces_recharge': 'payant',
#   'accessibilité': ' 24/24 7/7 jours',
#   'ad_station': 'place de la Grée - 44590 Derval',
#   'code_insee': Decimal('44051'),
#   'date_maj': Decimal('42892'),
#   'id_pdc': 'FR*S44*E44051A2',
#   'id_station': 'FR*S44*P44051A',
#   'n_amenageur': 'SYDELA',
#   'n_enseigne': 'SYDEGO',
#   'n_operateur': 'ENGIE Ineo',
#   'n_station': 'Station Derval',
#   'nbre_pdc': Decimal('2'),
#   'observations': None,
#   'puiss_max': Decimal('18'),
#   'source': 'data/leonard-du-mas-de-paysac/IRVE_SYDEGO_20180226.csv',
#   'type_prise': 'T2-E/F'},
#  {'Xlongitude': Decimal('3527472222'),
#   'Ylatitude': Decimal('435881806'),
#   'acces_recharge': '2|3',
#   'accessibilité': 'Informations tarifaires disponibles sur le site de RÉVÉO : https://www.reveocharge.com/fr/comment-ca-marche/tarifs-de-recharge/',
#   'ad_station': 'D 123 ( Parking Du Centre Culturel) 34230 LE POUGET',
#   'code_insee': Decimal('34210'),
#   'date_maj': '20/08/2018',
#   'id_pdc': 'FR*S34*E34210*001*1',
#   'id_station': 'FR*S34*P34210*001',
#   'n_amenageur': 'Herault Energies 34',
#   'n_enseigne': 'Révéo',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'LE POUGET - D 123 ( Parking Du Centre Culturel)',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Payant',
#   'puiss_max': Decimal('22'),
# ...
#   'ad_station': 'Rue De Bugarel 34000 MONTPELLIER',
#   'code_insee': Decimal('34172'),
#   'date_maj': '20/08/2018',
#   'id_pdc': 'FR*M34*E34172*022*1',
#   'id_station': 'FR*M34*P34172*022',
#   'n_amenageur': 'Montpellier Mediterranee Metropole',
#   'n_enseigne': 'Révéo',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'MONTPELLIER - Rue De Bugarel',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Payant',
#   'puiss_max': Decimal('22'),
#   'source': 'data/alexandre-court-2/IRVE_Reveo_20180820.csv',
#   'type_prise': 'T2 - EF'},
#  {'Xlongitude': Decimal('-4.722911'),
#   'Ylatitude': Decimal('48.403176'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24/24_7/7',
#   'ad_station': 'Place de la mairie - 29201 Ploumoguer',
#   'code_insee': Decimal('29201'),
#   'date_maj': datetime.date(2018, 4, 4),
#   'id_pdc': 'FRS29EJGEA2',
#   'id_station': 'FRS29PSDE29JGEA',
#   'n_amenageur': 'SDE29',
#   'n_enseigne': 'La borne �lectrique',
#   'n_operateur': 'Freshmile',
#   'n_station': 'Ploumoguer - Place de la mairie',
#   'nbre_pdc': Decimal('2'),
#   'observations': None,
#   'puiss_max': Decimal('22'),
#   'source': 'data/service-sig-sdef/IRVE_SDE29_20180404.csv',
#   'type_prise': 'T2-E/F'},
#  {'Xlongitude': Decimal('5.86157000'),
#   'Ylatitude': Decimal('43.28892900'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24/24 7/7 jours',
#   'ad_station': 'Chemin De La Rode 83870 SIGNES',
#   'code_insee': Decimal('83127'),
#   'date_maj': Decimal('20180629'),
#   'id_pdc': 'FR*S83*E83127*A*B1*G',
#   'id_station': 'FR*S83*P83127*A',
#   'n_amenageur': 'MOUVELECVAR',
#   'n_enseigne': None,
#   'n_operateur': 'MOUVELECVAR',
#   'n_station': 'SIGNES_Chemin De La Rode',
#   'nbre_pdc': None,
#   'observations': None,
#   'puiss_max': Decimal('22.00'),
#   'source': 'data/symielecvar-symielec/IRVE_MOUVELECVAR_20180629.csv',
#   'type_prise': 'E/F + T2'},
#  {'Xlongitude': Decimal('-1.07290148'),
#   'Ylatitude': Decimal('44.35328576'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24h/24 et 7j/7',
#   'ad_station': 'Parking Mairie- Avenue Germinal 40160 PARENTIS EN BORN',
#   'code_insee': Decimal('40217'),
#   'date_maj': '25/06/2018',
#   'id_pdc': 'FR*S40*E40217*001*3',
#   'id_station': 'FR*S40*P40217*001',
#   'n_amenageur': 'SYDEC 40',
#   'n_enseigne': 'MObiVE',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'PARENTIS EN BORN - Parking Mairie- Avenue Germinal',
#   'nbre_pdc': Decimal('4'),
#   'observations': 'Recharge par badge et avec une application smartphone',
#   'puiss_max': Decimal('50'),
#   'source': 'data/alexandre-court-2/IRVE_MObiVE_20180625.csv',
#   'type_prise': 'COMBO'},
#  {'Xlongitude': Decimal('4.32584200'),
#   'Ylatitude': Decimal('44.53750900'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24/24 7/7 jours',
#   'ad_station': 'Place Chalendas 07110 VINEZAC',
#   'code_insee': Decimal('7343'),
#   'date_maj': Decimal('20180905'),
#   'id_pdc': 'FR*S07*E07343*A*B1*D',
#   'id_station': 'FR*S07*P07343*A',
#   'n_amenageur': 'SDE07',
#   'n_enseigne': 'E Born',
#   'n_operateur': 'SDE07',
#   'n_station': 'VINEZAC_Place Chalendas',
#   'nbre_pdc': None,
#   'observations': None,
#   'puiss_max': Decimal('22.00'),
#   'source': 'data/syndicat-departemental-denergies-de-lardeche/irve-sde07-20180905.csv',
#   'type_prise': 'E/F + T2'},
#  {'Xlongitude': Decimal('407218'),
#   'Ylatitude': Decimal('43222203'),
#   'acces_recharge': '2|3',
#   'accessibilité': 'Informations tarifaires disponibles sur le site de RÉVÉO : https://www.reveocharge.com/fr/comment-ca-marche/tarifs-de-recharge/',
#   'ad_station': 'Centre 65330 GALAN',
#   'code_insee': Decimal('65184'),
#   'date_maj': '20/08/2018',
#   'id_pdc': 'FR*S65*E65184*001*2',
#   'id_station': 'FR*S65*P65184*001',
#   'n_amenageur': 'SDE 65',
#   'n_enseigne': 'Révéo',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'GALAN - Centre',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Payant',
#   'puiss_max': Decimal('18'),
#   'source': 'data/alexandre-court-2/IRVE_Reveo_20180820.csv',
#   'type_prise': 'T2 - EF'},
#  {'Xlongitude': Decimal('0.397276'),
#   'Ylatitude': Decimal('49.417993'),
#   'acces_recharge': 'payant',
#   'accessibilité': '24/24 7/7 jours',
#   'ad_station': 'Place du Prebytere Conteville',
#   'code_insee': Decimal('27169'),
#   'date_maj': datetime.date(2017, 2, 10),
#   'id_pdc': 'FR*S27*ECONTEVILLE*PRESBYTERED',
#   'id_station': 'FR*S27*PCONTEVILLE*PRESBYTERE',
#   'n_amenageur': 'SIEGE 27',
#   'n_enseigne': 'SIEGE 27',
#   'n_operateur': 'SIEGE 27',
#   'n_station': Decimal('900028'),
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Borne en service',
#   'puiss_max': Decimal('22.0'),
#   'source': 'data/christophe-gaillard/IRVE_SIEGE27_20171130.csv',
#   'type_prise': 'E/F-T2'},
#  {'Xlongitude': Decimal('35989842709'),
#   'Ylatitude': Decimal('477380126412'),
#   'acces_recharge': 'gratuit',
#   'accessibilité': '24/24 - 7/7',
#   'ad_station': 'Place Saint Louis - CHAMPS SUR YONNE',
#   'code_insee': Decimal('89077'),
#   'date_maj': Decimal('20170519'),
#   'id_pdc': 'FR S89 E89077 A B1 D',
#   'id_station': 'FR S89 P89077 A',
#   'n_amenageur': "SDEY Syndicat Departemental d'Energies de l'Yonne",
#   'n_enseigne': None,
#   'n_operateur': 'SPIE',
#   'n_station': 'Place Saint Louis',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'En service',
#   'puiss_max': Decimal('22'),
#   'source': 'data/patrice-lozere/IRVE_SDEY_YONNE_20170519.csv',
#   'type_prise': 'T2 - E/F'},
#  {'Xlongitude': Decimal('-0.384321'),
#   'Ylatitude': Decimal('43.314882'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24h/24 et 7j/7',
#   'ad_station': 'Avenue Du Tonkin  64140 BILLERE',
#   'code_insee': Decimal('64129'),
#   'date_maj': '25/06/2018',
#   'id_pdc': 'FR*S64*E64129*001*1',
#   'id_station': 'FR*S64*P64129*002',
#   'n_amenageur': 'SDEPA 64',
#   'n_enseigne': 'MObiVE',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'BILLERE - Avenue Du Tonkin',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Recharge par badge et avec une application smartphone',
#   'puiss_max': Decimal('18'),
#   'source': 'data/alexandre-court-2/IRVE_MObiVE_20180625.csv',
#   'type_prise': 'T2 - EF'},
#  {'Xlongitude': '-0.3532908',
#   'Ylatitude': Decimal('46.65044958'),
#   'acces_recharge': 'payant',
#   'accessibilité': '24/24 7/7 jours',
#   'ad_station': "Place de l'Eglise - 79300 ST AUBIN LE CLOUD",
#   'code_insee': Decimal('79239'),
#   'date_maj': '13/02/2017',
#   'id_pdc': 'FRSEOEAB28009A12 ',
#   'id_station': 'FRSEOPAB28009A',
#   'n_amenageur': 'S‚olis',
#   'n_enseigne': 'AlterBase',
#   'n_operateur': 'S‚olis',
#   'n_station': "R‚seau AlterBase - St Aubin le Cloud - Place de l'Eglise",
#   'nbre_pdc': Decimal('2'),
#   'observations': 'www.alterbase.fr',
#   'puiss_max': Decimal('3.18'),
#   'source': 'data/david-baufreton/IRVE_reseauAlterBase_20171116.CSV.csv',
#   'type_prise': 'E/F-T3'},
#  {'Xlongitude': Decimal('-1.167335'),
#   'Ylatitude': Decimal('44.395639'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24h/24 et 7j/7',
#   'ad_station': 'Parking Mairie 40600 BISCAROSSE',
#   'code_insee': Decimal('40046'),
#   'date_maj': '25/06/2018',
#   'id_pdc': 'FR*S40*E40046*001*2',
#   'id_station': 'FR*S40*P40046*001',
#   'n_amenageur': 'SYDEC 40',
#   'n_enseigne': 'MObiVE',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'BISCAROSSE - Parking Mairie',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Recharge par badge et avec une application smartphone',
#   'puiss_max': Decimal('18'),
#   'source': 'data/alexandre-court-2/IRVE_MObiVE_20180625.csv',
#   'type_prise': 'T2 - EF'},
#  {'Xlongitude': Decimal('4311872'),
#   'Ylatitude': Decimal('43787437'),
#   'acces_recharge': '2|3',
#   'accessibilité': 'Informations tarifaires disponibles sur le site de RÉVÉO : https://www.reveocharge.com/fr/comment-ca-marche/tarifs-de-recharge/',
#   'ad_station': 'Rue Des Troenes 30540 MILHAUD',
#   'code_insee': Decimal('30169'),
#   'date_maj': '20/08/2018',
#   'id_pdc': 'FR*S30*E30169*001*2',
#   'id_station': 'FR*S30*P30169*001',
#   'n_amenageur': 'SMEG 30',
#   'n_enseigne': 'Révéo',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'MILHAUD - Rue Des Troenes',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Payant',
#   'puiss_max': Decimal('18'),
#   'source': 'data/alexandre-court-2/IRVE_Reveo_20180820.csv',
#   'type_prise': 'EF - T2 - T3'},
#  {'Xlongitude': Decimal('4.86794'),
#   'Ylatitude': Decimal('45.52920'),
#   'acces_recharge': '5€ / 45min, si abonné (10€/mois) : 1€/10min',
#   'accessibilité': '24h/24 7j/7',
#   'ad_station': 'Rue des Thermes',
#   'code_insee': Decimal('69235'),
#   'date_maj': datetime.date(2018, 11, 4),
#   'id_pdc': 'FR*CN1*EMUQN*1',
#   'id_station': 'FR*CN1*PPBFBFV',
#   'n_amenageur': 'CNR',
#   'n_enseigne': 'move in pure',
#   'n_operateur': 'Freshmile',
#   'n_station': 'Saint-Romain-en-Gal',
#   'nbre_pdc': Decimal('2'),
#   'puiss_max': Decimal('50'),
#   'source': 'data/cnr/IRVE_CNR_20180420.csv',
#   'type_prise': 'T2-Combo2-CHAdeMO'},
#  {'Xlongitude': Decimal('-0.96217089'),
#   'Ylatitude': Decimal('44.32789993'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24h/24 et 7j/7',
#   'ad_station': 'Parking De La Mairie Avenue Felix Arnaudin 40160 YCHOUX',
#   'code_insee': Decimal('40332'),
#   'date_maj': '25/06/2018',
#   'id_pdc': 'FR*S40*E40332*002*4',
#   'id_station': 'FR*S40*P40332*002',
#   'n_amenageur': 'SYDEC 40',
#   'n_enseigne': 'MObiVE',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'YCHOUX - Parking De La Mairie Avenue Felix Arnaudin',
#   'nbre_pdc': Decimal('4'),
#   'observations': 'Recharge par badge et avec une application smartphone',
#   'puiss_max': Decimal('4'),
#   'source': 'data/alexandre-court-2/IRVE_MObiVE_20180625.csv',
#   'type_prise': 'EF'},
#  {'Xlongitude': Decimal('199758'),
#   'Ylatitude': Decimal('43760724'),
#   'acces_recharge': '2|3',
#   'accessibilité': 'Informations tarifaires disponibles sur le site de RÉVÉO : https://www.reveocharge.com/fr/comment-ca-marche/tarifs-de-recharge/',
#   'ad_station': 'Cinéma Vertigo 81300 GRAULHET',
#   'code_insee': Decimal('81105'),
#   'date_maj': '20/08/2018',
#   'id_pdc': 'FR*S81*E81105*002*1',
#   'id_station': 'FR*S81*P81105*002',
#   'n_amenageur': 'SDET 81',
#   'n_enseigne': 'Révéo',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'GRAULHET - Cinéma Vertigo',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Payant',
#   'puiss_max': Decimal('18'),
#   'source': 'data/alexandre-court-2/IRVE_Reveo_20180820.csv',
#   'type_prise': 'EF - T2 - T3'},
#  {'Xlongitude': Decimal('-1210774'),
#   'Ylatitude': Decimal('48355364'),
#   'acces_recharge': 'Gratuit',
#   'accessibilité': '24h/24 et 7j/7',
#   'ad_station': 'Parking Du Rocher Coupe 35300 FOUGERES',
#   'code_insee': Decimal('35115'),
#   'date_maj': '28/05/2018',
#   'id_pdc': 'FR*S35*E35115*003*2',
#   'id_station': 'FR*S35*P35115*003',
#   'n_amenageur': 'SDE 35',
#   'n_enseigne': 'SDE35',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'FOUGERES - Parking Du Rocher Coupe',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Recharge par badge et avec une application smartphone',
#   'puiss_max': Decimal('18'),
#   'source': 'data/alexandre-court-2/IRVE_SDE35_20180528.csv',
#   'type_prise': 'T3 - EF'},
#  {'Xlongitude': Decimal('1.0118'),
#   'Ylatitude': Decimal('43.2001'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24h/24 7j/7',
#   'ad_station': 'Boulevard de Magdeleine 31220 Martres-Tolosane',
#   'code_insee': Decimal('31324'),
#   'date_maj': datetime.date(2018, 3, 29),
#   'id_pdc': 'FR*S31*ECWFC*1',
#   'id_station': 'FR*S31*PHQDVPR',
#   'n_amenageur': 'SDEHG',
#   'n_enseigne': 'Roulez Électrique en Haute-Garonne',
#   'n_operateur': 'Freshmile',
#   'n_station': 'Martres-Tolosane',
#   'nbre_pdc': Decimal('2'),
#   'puiss_max': '18 kW',
#   'source': 'data/servane-macheto/IRVE_SDEHG_20180720.csv',
#   'type_prise': 'T2 - E/F'},
#  {'Xlongitude': Decimal('2138264'),
#   'Ylatitude': Decimal('43919878'),
#   'acces_recharge': '2|3',
#   'accessibilité': 'Informations tarifaires disponibles sur le site de RÉVÉO : https://www.reveocharge.com/fr/comment-ca-marche/tarifs-de-recharge/',
#   'ad_station': 'Avenue Francois Verdier 81000 ALBI',
#   'code_insee': Decimal('81004'),
#   'date_maj': '20/08/2018',
#   'id_pdc': 'FR*S81*E81004*006*2',
#   'id_station': 'FR*S81*P81004*006',
#   'n_amenageur': 'SDET 81',
#   'n_enseigne': 'Révéo',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'ALBI - Avenue Francois Verdier',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Payant',
#   'puiss_max': Decimal('22'),
#   'source': 'data/alexandre-court-2/IRVE_Reveo_20180820.csv',
#   'type_prise': 'EF - T2 - T3'},
#  {'Xlongitude': Decimal('5527'),
#   'Ylatitude': Decimal('4338707'),
#   'acces_recharge': '2|3',
#   'accessibilité': 'Informations tarifaires disponibles sur le site de RÉVÉO : https://www.reveocharge.com/fr/comment-ca-marche/tarifs-de-recharge/',
#   'ad_station': 'Parking centre multimédia 65500 VIC BIGORRE',
#   'code_insee': Decimal('65460'),
#   'date_maj': '20/08/2018',
#   'id_pdc': 'FR*S65*E65460*001*1',
#   'id_station': 'FR*S65*P65460*001',
#   'n_amenageur': 'SDE 65',
#   'n_enseigne': 'Révéo',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'VIC BIGORRE - parking centre multimédia',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Payant',
#   'puiss_max': Decimal('18'),
#   'source': 'data/alexandre-court-2/IRVE_Reveo_20180820.csv',
#   'type_prise': 'T2 - EF'},
#  {'Xlongitude': Decimal('1.21595'),
#   'Ylatitude': Decimal('43.4657'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24h/24 7j/7',
#   'ad_station': 'Grand Place 31600 Saint-Clar-de-Rivière',
#   'code_insee': Decimal('31475'),
#   'date_maj': datetime.date(2018, 3, 29),
#   'id_pdc': 'FR*S31*ELMDK*1',
#   'id_station': 'FR*S31*PZJVBJM',
#   'n_amenageur': 'SDEHG',
#   'n_enseigne': 'Roulez Électrique en Haute-Garonne',
#   'n_operateur': 'Freshmile',
#   'n_station': 'Saint-Clar-de-Rivière, Grand Place',
#   'nbre_pdc': Decimal('2'),
#   'puiss_max': '18 kW',
#   'source': 'data/servane-macheto/IRVE_SDEHG_20180720.csv',
#   'type_prise': 'T2 - E/F'},
#  {'Xlongitude': Decimal('5.84238700'),
#   'Ylatitude': Decimal('43.87671500'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24/24 7/7 jours',
#   'ad_station': 'Parking Mairie 04130 VOLX',
#   'code_insee': Decimal('4245'),
#   'date_maj': Decimal('20180329'),
#   'id_pdc': 'FR*S04*E04245*A*B1*G',
#   'id_station': 'FR*S04*P04245*A',
#   'n_amenageur': 'SDE04',
#   'n_enseigne': None,
#   'n_operateur': 'SDE04',
#   'n_station': 'VOLX_Parking Mairie',
#   'nbre_pdc': '1',
#   'observations': None,
#   'puiss_max': '22',
#   'source': 'data/region-provence-alpes-cote-d-azur/bornes-recharge-agregation-region-reference.csv',
#   'type_prise': 'E/F + T2'},
#  {'Xlongitude': Decimal('5.98638200'),
#   'Ylatitude': Decimal('43.83649300'),
#   'acces_recharge': 'Payant',
#   'accessibilité': '24/24 7/7 jours',
#   'ad_station': 'Parking Salle Polyvalente 04210 VALENSOLE',
#   'code_insee': Decimal('4230'),
#   'date_maj': Decimal('20180329'),
#   'id_pdc': 'FR*S04*E04230*A*B1*D',
#   'id_station': 'FR*S04*P04230*A',
#   'n_amenageur': 'SDE04',
#   'n_enseigne': None,
#   'n_operateur': 'SDE04',
#   'n_station': 'VALENSOLE_Parking Salle Polyvalente',
#   'nbre_pdc': '1',
#   'observations': None,
#   'puiss_max': '22',
#   'source': 'data/region-provence-alpes-cote-d-azur/bornes-recharge-agregation-region-reference.csv',
#   'type_prise': 'E/F + T2'},
#  {'Xlongitude': Decimal('3222073317'),
#   'Ylatitude': Decimal('4334787405'),
#   'acces_recharge': '2|3',
#   'accessibilité': 'Informations tarifaires disponibles sur le site de RÉVÉO : https://www.reveocharge.com/fr/comment-ca-marche/tarifs-de-recharge/',
#   'ad_station': 'Av Jean Moulin 34500 BEZIERS',
#   'code_insee': Decimal('34032'),
#   'date_maj': '20/08/2018',
#   'id_pdc': 'FR*S34*E34032*004*1',
#   'id_station': 'FR*S34*P34032*004',
#   'n_amenageur': 'Herault Energies 34',
#   'n_enseigne': 'Révéo',
#   'n_operateur': 'BOUYGUES ENERGIES ET SERVICES',
#   'n_station': 'BEZIERS - Av Jean Moulin',
#   'nbre_pdc': Decimal('2'),
#   'observations': 'Payant',
#   'puiss_max': Decimal('22'),
#   'source': 'data/alexandre-court-2/IRVE_Reveo_20180820.csv',
#   'type_prise': 'EF - T2 - T3'},
#  ...]

# %%
len(bornes), len([b for b in bornes if b['id_pdc']]), len(unique_bornes)
# Out:
# (14173, 12657, 9819)

# %%
# enjoy the results!

import csv

with open('bornes-IRVE.csv', 'w') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=columns + ['source'], delimiter=';')
    writer.writeheader()
    for b in unique_bornes:
        writer.writerow(b)
